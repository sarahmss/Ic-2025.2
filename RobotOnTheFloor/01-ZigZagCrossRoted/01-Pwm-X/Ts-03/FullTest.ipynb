# %% [markdown]
# # RNN
# - 2 Entradas PwmD, PwmE
# - 1 Saida  $\Delta$ X
# - 1 Camada
# - n neurônios

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
TARGET = ["X"]       
TIME_STEPS = 3

for i in range(4):
    Dataset = pd.read_excel(f"../../RotedData/Data.xlsx", f"D{i+1}")   
    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]    
           
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../RotedData/Data{i + 1}.csv")
        
    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]    
    
    Datasets.append(Dataset)
    

for i in range(len(Datasets)):
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Dataset.head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0
# ++++++++++++++++++++ Dataset 5 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0
# ++++++++++++++++++++ Dataset 6 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaX
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.28   3.28  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.28   3.28  49.25  49.25     0.0
# 3  0.0  0.7    0.0  0.14  0.0   3.28   3.28  49.25  49.25     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.27   3.27  66.69  68.80     0.0

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]

    # Dropar apenas uma vez (mantém apenas linhas onde todos os deltas existem)
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET])

    Datasets[i] = Dataset

    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef   PwmD   PwmE  \
# 971       67.97  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -52.65 -29.75
# 972       68.04  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -47.56 -17.83
# 973       68.11  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -47.56 -17.83
# 974       68.18  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -42.47  -5.67
# 975       68.25  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -42.47  -5.67
#
#      DeltaX
# 971     0.0
# 972     0.0
# 973     0.0
# 974     0.0
# 975     0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  \
# 971       67.97  0.04  0.66  -0.78 -2.40 -1.81  -3.20  -3.17 -112.80 -122.28
# 972       68.04  0.04  0.67  -0.79 -2.93 -2.43  -3.27  -3.29 -112.80 -122.28
# 973       68.11  0.03  0.67  -0.79 -3.29 -3.09  -3.14  -3.17 -107.79 -120.76
# 974       68.18  0.03  0.68  -0.79 -3.26 -3.21  -2.96  -3.01 -107.79 -120.76
# 975       68.25  0.02  0.68  -0.79 -3.18 -3.21  -2.74  -2.80  -98.04 -108.00
#
#      DeltaX
# 971    0.00
# 972   -0.01
# 973    0.00
# 974   -0.01
# 975    0.00
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef   PwmD   PwmE  \
# 977       68.39  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -58.81 -46.33
# 978       68.46  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -53.90 -38.47
# 979       68.53  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -53.90 -38.47
# 980       68.60  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -48.98 -26.60
# 981       68.67  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -48.98 -26.60
#
#      DeltaX
# 977     0.0
# 978     0.0
# 979     0.0
# 980     0.0
# 981     0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  \
# 977       68.39  0.04  0.66  -0.77 -3.68 -3.07  -3.27  -3.29 -100.01 -115.88
# 978       68.46  0.04  0.66  -0.78 -3.68 -3.01  -3.07  -3.11 -100.01 -115.88
# 979       68.53  0.03  0.67  -0.79 -3.37 -3.09  -2.09  -2.40  -80.69 -106.52
# 980       68.60  0.03  0.67  -0.78 -2.68 -2.79  -1.25  -2.15  -80.69 -106.52
# 981       68.67  0.02  0.68  -0.78 -2.31 -2.62  -1.12  -2.12  -71.69 -101.95
#
#      DeltaX
# 977    0.00
# 978   -0.01
# 979    0.00
# 980   -0.01
# 981    0.00
# ++++++++++++++++++++ Dataset 5 +++++++++++++++++++++++
#          X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaX
# 1948  0.04  0.66  -0.78 -2.40 -1.81  -3.20  -3.17 -112.80 -122.28    0.00
# 1949  0.04  0.67  -0.79 -2.93 -2.43  -3.27  -3.29 -112.80 -122.28   -0.01
# 1950  0.03  0.67  -0.79 -3.29 -3.09  -3.14  -3.17 -107.79 -120.76    0.00
# 1951  0.03  0.68  -0.79 -3.26 -3.21  -2.96  -3.01 -107.79 -120.76   -0.01
# 1952  0.02  0.68  -0.79 -3.18 -3.21  -2.74  -2.80  -98.04 -108.00    0.00
# ++++++++++++++++++++ Dataset 6 +++++++++++++++++++++++
#          X     Y  Theta    Wd    We  WdRef  WeRef   PwmD    PwmE  DeltaX
# 1948  0.09  0.61  -0.76 -3.79 -1.87  -2.17  -1.35 -93.89  -98.60    0.00
# 1949  0.09  0.62  -0.79 -3.09 -1.42  -3.29  -3.27 -93.89  -98.60   -0.01
# 1950  0.08  0.62  -0.81 -3.04 -1.78  -1.75  -2.28 -81.85 -113.38    0.00
# 1951  0.08  0.62  -0.81 -1.67 -1.76  -1.02  -2.11 -81.85 -113.38    0.00
# 1952  0.08  0.63  -0.80 -1.78 -2.31  -1.02  -2.11 -84.14 -110.88   -0.01

# %%
NormDatasets = []
TARGET = ["DeltaX"]

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

# ===== TRAIN FASE 1 =====
Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

# ===== TRAIN FASE 2 =====
Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)


for i in range(4):
      CurrentTestDataset = Datasets[i + 2]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+2} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#    Unnamed: 0    X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.0  0.7   0.00  0.00  0.0   0.00   0.00  0.221564  0.111917
# 1        0.07  0.0  0.7   0.00  0.00  0.0   3.28   3.28  0.221564  0.111917
# 2        0.14  0.0  0.7   0.00  0.00  0.0   3.28   3.28  0.803114  0.594038
# 3        0.21  0.0  0.7   0.00  0.06  0.0   3.28   3.28  0.803114  0.594038
# 4        0.28  0.0  0.7   0.01  0.33  0.0   3.28   3.28  1.025343  0.786494
#
#      DeltaX
# 0 -0.001615
# 1 -0.001615
# 2 -0.001615
# 3 -0.001615
# 4 -0.001615
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#    Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.219706  0.175547
# 1        0.07  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.159602  0.294682
# 2        0.14  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.159602  0.294682
# 3        0.21  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.099381  0.413720
# 4        0.28  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.099381  0.413720
#
#      DeltaX
# 0 -0.001615
# 1 -0.001615
# 2 -0.001615
# 3 -0.001615
# 4 -0.001615
# ++++++++++++++++++++ Dataset Normalizado 4 +++++++++++++++++++++++
#    Unnamed: 0    X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.0  0.7    0.0  0.00  0.0   0.00   0.00  0.221564  0.111917
# 1        0.07  0.0  0.7    0.0  0.00  0.0   3.28   3.28  0.221564  0.111917
# 2        0.14  0.0  0.7    0.0  0.00  0.0   3.28   3.28  0.803114  0.594038
# 3        0.21  0.0  0.7    0.0  0.14  0.0   3.28   3.28  0.803114  0.594038
# 4        0.28  0.0  0.7    0.0  0.00  0.0   3.27   3.27  1.009048  0.785417
#
#      DeltaX
# 0 -0.001615
# 1 -0.001615
# 2 -0.001615
# 3 -0.001615
# 4 -0.001615
# ++++++++++++++++++++ Dataset Normalizado 5 +++++++++++++++++++++++
#    Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.298820 -0.032278
# 1        0.07  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.240724  0.083920
# 2        0.14  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.240724  0.083920
# 3        0.21  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.182746  0.200118
# 4        0.28  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.182746  0.200118
#
#      DeltaX
# 0 -0.001615
# 1 -0.001615
# 2 -0.001615
# 3 -0.001615
# 4 -0.001615

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train1, y_train1 = CreateSequences(Train1[PREDICTORS], Train1[TARGET], TIME_STEPS)

x_train2, y_train2 = CreateSequences(Train2[PREDICTORS], Train2[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)

print(f"Dimensão da entrada: {np.shape(x_train1)}")
print(f"Dimensão da saida: {np.shape(y_train1)}")

print(f"Dimensão da entrada: {np.shape(x_train2)}")
print(f"Dimensão da saida: {np.shape(y_train2)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (1950, 3, 2)
# Dimensão da saida: (1950, 3, 2)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def PlotOut(ax, title, target_name, y_true, y_pred):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true, marker='o', s=12, label='Amostras Reais', alpha=0.7)
    ax.scatter(time, y_pred, marker='x', s=12, label='Valores Preditos', alpha=0.7)
    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_datasets = len(Datasets)
    n_targets = len(TARGET)
    fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    
    metrics = {name: {"R2_train1": [], "R2_train2": [],
                      "R2_test1": [], "R2_test2": [],
                      "R2_test3": [],"R2_val": [],
                      "MSE_train1": [], "MSE_train2": [],
                      "MSE_test1": [], "MSE_test2": [],
                      "MSE_test3": [], "MSE_val": [],} for name in TARGET}

    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)
        
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)

        # valores iniciais reais (não normalizados)
        init_vals = np.array([
            Datasets[i]["Theta"].iloc[0],
            Datasets[i]["X"].iloc[0],
            Datasets[i]["Y"].iloc[0]
        ])

        # reconstrução cumulativa saída a saída
        for j, name in enumerate(TARGET):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j])
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j])


        # Calcula métricas por saída
        for j, name in enumerate(TARGET):
            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])
            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, MSE = {mse:.4e}")
            
            # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
                axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            )
            PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j])

    plt.tight_layout()

    # Retorna métricas médias para análise posterior
    return metrics, plt, fig

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras import initializers

# tamanho da entrada
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 
N_MODELS = 10  # número de inicializações

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)
neurons = [12, 14, 16, 18, 19, 20, 21, 22, 23, 24, 25]
results = {}
excel_file = "resultados.xlsx"

for n in neurons:
    for i, s in enumerate(seeds):

        initializer = initializers.RandomNormal(seed=int(s))

        # cria modelo
        model = keras.models.Sequential([
            keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)),
            keras.layers.SimpleRNN(n, activation="tanh", kernel_initializer=initializer),
            keras.layers.Dense(OUTPUT_SIZE, activation="linear", kernel_initializer=initializer),  
        ])
        
        # salva pesos iniciais
        w0 = model.get_weights()

        # compila
        model.compile(loss="mean_squared_error", optimizer="adam")
        early_stopping_monitor = EarlyStopping(
            monitor='val_loss',
            patience=50,
            restore_best_weights=True
        )

        # ===== TREINO FASE 1 =====
        history = model.fit(
            x_train1, 
            y_train1, 
            epochs=500,
            callbacks=[early_stopping_monitor],
            validation_data=(x_val, y_val),
            verbose=0
        )
        
        # salva pesos após fase 1
        w_after_1 = model.get_weights()

        # ===== TREINO FASE 2 (continua pesos) =====
        model.fit(
            x_train2,
            y_train2,
            epochs=300,
            validation_data=(x_val, y_val),
            callbacks=[early_stopping_monitor],
            verbose=0
        )

        # salva pesos finais
        wf = model.get_weights()

       # avalia o modelo
        metrics, plt, fig = EvalModel(model)


        row = {
            "model": f"model_{n}_{i}",
            "Neurons": n,
            "W0": str([w.round(4).tolist() for w in w0]),
            "W_after_train1": str([w.round(4).tolist() for w in w_after_1]),
            "W_final": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET:
            row.update({
                f"R2_Train_1{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.5 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{n}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{n}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.1130, MSE = 2.2784e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.6603, MSE = 1.3990e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.2321, MSE = 2.3384e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.7404, MSE = 1.4323e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -0.8275, MSE = 1.8429e-01
# 61/61 [==============================] - 0s 5ms/step
# DeltaX | val -> R² = -1.0100, MSE = 1.9656e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -0.9748, MSE = 2.1294e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.4459, MSE = 1.2183e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.0797, MSE = 2.1787e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -0.5049, MSE = 1.2385e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -0.5426, MSE = 1.5556e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -0.6685, MSE = 1.6317e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3086, MSE = 2.4892e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.7933, MSE = 1.5110e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.4225, MSE = 2.5379e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -0.8653, MSE = 1.5350e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.0083, MSE = 2.0253e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.1875, MSE = 2.1393e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.2129, MSE = 2.3861e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.7435, MSE = 1.4691e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.3335, MSE = 2.4446e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8218, MSE = 1.4992e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -0.9627, MSE = 1.9793e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.1539, MSE = 2.1064e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# DeltaX | train1 -> R² = -1.4061, MSE = 2.5944e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | train2 -> R² = -0.8276, MSE = 1.5399e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test1 -> R² = -1.5361, MSE = 2.6568e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test2 -> R² = -0.8901, MSE = 1.5554e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.0822, MSE = 2.0998e-01
# 61/61 [==============================] - 0s 5ms/step
# DeltaX | val -> R² = -1.2661, MSE = 2.2162e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5539, MSE = 2.7538e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0224, MSE = 1.7041e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6691, MSE = 2.7962e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0924, MSE = 1.7219e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.3584, MSE = 2.3783e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.5558, MSE = 2.4995e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3133, MSE = 2.4943e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.8019, MSE = 1.5183e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.4293, MSE = 2.5450e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8739, MSE = 1.5421e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.0303, MSE = 2.0475e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.2135, MSE = 2.1647e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.2373, MSE = 2.4124e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.7469, MSE = 1.4719e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.3575, MSE = 2.4697e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -0.8223, MSE = 1.4996e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -0.9595, MSE = 1.9761e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.1455, MSE = 2.0982e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.7402, MSE = 2.9546e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1767, MSE = 1.8341e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.8553, MSE = 2.9912e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.2403, MSE = 1.8437e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.5825, MSE = 2.6043e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.7818, MSE = 2.7204e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# DeltaX | train1 -> R² = -1.3712, MSE = 2.5568e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.8467, MSE = 1.5560e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.4919, MSE = 2.6105e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9184, MSE = 1.5787e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.0967, MSE = 2.1144e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.2858, MSE = 2.2354e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.4811, MSE = 2.6753e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9184, MSE = 1.6165e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.5974, MSE = 2.7211e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9823, MSE = 1.6313e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.1973, MSE = 2.2159e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3799, MSE = 2.3274e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5540, MSE = 2.7538e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | train2 -> R² = -0.9304, MSE = 1.6266e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6544, MSE = 2.7807e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9796, MSE = 1.6291e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.1661, MSE = 2.1844e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3186, MSE = 2.2675e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.4949, MSE = 2.6902e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.9421, MSE = 1.6364e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.6062, MSE = 2.7303e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0078, MSE = 1.6523e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2134, MSE = 2.2321e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3946, MSE = 2.3417e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.2218, MSE = 2.3957e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.7306, MSE = 1.4582e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.3417, MSE = 2.4531e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8049, MSE = 1.4853e-01
# 61/61 [==============================] - 0s 5ms/step
# DeltaX | test3 -> R² = -0.9367, MSE = 1.9531e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.1202, MSE = 2.0734e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6078, MSE = 2.8119e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0638, MSE = 1.7390e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.7202, MSE = 2.8497e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -1.1305, MSE = 1.7532e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.4077, MSE = 2.4280e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.6015, MSE = 2.5442e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 2ms/step
# DeltaX | train1 -> R² = -1.3833, MSE = 2.5698e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.7996, MSE = 1.5163e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.4823, MSE = 2.6005e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8557, MSE = 1.5272e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -0.9901, MSE = 2.0070e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.1400, MSE = 2.0928e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6050, MSE = 2.8089e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0446, MSE = 1.7228e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7119, MSE = 2.8410e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test2 -> R² = -1.1076, MSE = 1.7344e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.3656, MSE = 2.3856e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.5485, MSE = 2.4923e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3687, MSE = 2.5541e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.8021, MSE = 1.5184e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.4643, MSE = 2.5816e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8620, MSE = 1.5323e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -0.9836, MSE = 2.0004e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.1340, MSE = 2.0870e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.4154, MSE = 2.6044e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -0.8425, MSE = 1.5525e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.5340, MSE = 2.6546e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9039, MSE = 1.5668e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.0893, MSE = 2.1069e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.2648, MSE = 2.2149e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.4463, MSE = 2.6377e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9002, MSE = 1.6011e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.5540, MSE = 2.6756e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9658, MSE = 1.6177e-01
# 61/61 [==============================] - 0s 7ms/step
# DeltaX | test3 -> R² = -1.1548, MSE = 2.1730e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.3307, MSE = 2.2793e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6724, MSE = 2.8815e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0570, MSE = 1.7333e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7793, MSE = 2.9117e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1089, MSE = 1.7354e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.3677, MSE = 2.3877e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.5375, MSE = 2.4815e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6575, MSE = 2.8655e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1048, MSE = 1.7735e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7677, MSE = 2.8995e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1709, MSE = 1.7865e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.4563, MSE = 2.4771e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.6487, MSE = 2.5903e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5139, MSE = 2.7106e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9986, MSE = 1.6841e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6249, MSE = 2.7498e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.0711, MSE = 1.7044e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.3166, MSE = 2.3362e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.5117, MSE = 2.4564e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6907, MSE = 2.9013e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1774, MSE = 1.8347e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.8024, MSE = 2.9358e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.2509, MSE = 1.8524e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.5890, MSE = 2.6109e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.7982, MSE = 2.7365e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6451, MSE = 2.8520e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1069, MSE = 1.7753e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.7545, MSE = 2.8857e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1753, MSE = 1.7901e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.4683, MSE = 2.4892e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.6638, MSE = 2.6051e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train1 -> R² = -1.5994, MSE = 2.8029e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0551, MSE = 1.7316e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7240, MSE = 2.8536e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1241, MSE = 1.7480e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.4290, MSE = 2.4495e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.6355, MSE = 2.5774e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6450, MSE = 2.8519e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | train2 -> R² = -1.0551, MSE = 1.7317e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.7297, MSE = 2.8596e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1091, MSE = 1.7356e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2892, MSE = 2.3085e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.4402, MSE = 2.3864e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.4610, MSE = 2.6536e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9795, MSE = 1.6679e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.5567, MSE = 2.6784e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0577, MSE = 1.6933e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.2515, MSE = 2.2705e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4374, MSE = 2.3837e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3972, MSE = 2.5848e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.8626, MSE = 1.5694e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.4983, MSE = 2.6172e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -0.9293, MSE = 1.5877e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.0859, MSE = 2.1036e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.2545, MSE = 2.2047e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5663, MSE = 2.7671e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9944, MSE = 1.6805e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6626, MSE = 2.7893e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0537, MSE = 1.6901e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2544, MSE = 2.2735e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4192, MSE = 2.3659e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.7939, MSE = 3.0125e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | train2 -> R² = -1.2473, MSE = 1.8936e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test1 -> R² = -1.9076, MSE = 3.0460e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.3137, MSE = 1.9040e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.6928, MSE = 2.7155e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.8992, MSE = 2.8353e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.7971, MSE = 3.0160e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -1.2501, MSE = 1.8960e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.9013, MSE = 3.0395e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.3148, MSE = 1.9049e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.6575, MSE = 2.6800e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.8526, MSE = 2.7897e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5674, MSE = 2.7683e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9927, MSE = 1.6790e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6646, MSE = 2.7915e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0517, MSE = 1.6884e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.2510, MSE = 2.2700e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4159, MSE = 2.3627e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.5826, MSE = 2.7847e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -1.0085, MSE = 1.6924e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.6868, MSE = 2.8147e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -1.0685, MSE = 1.7023e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.2943, MSE = 2.3137e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.4679, MSE = 2.4135e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.7350, MSE = 2.9490e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1079, MSE = 1.7762e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.8474, MSE = 2.9830e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1582, MSE = 1.7760e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.4488, MSE = 2.4695e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.6243, MSE = 2.5664e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.4646, MSE = 2.6574e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.8666, MSE = 1.5728e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.5605, MSE = 2.6824e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9213, MSE = 1.5811e-01
# 61/61 [==============================] - 0s 6ms/step
# DeltaX | test3 -> R² = -1.0662, MSE = 2.0837e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.2154, MSE = 2.1665e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.6789, MSE = 2.8886e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.1113, MSE = 1.7790e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7977, MSE = 2.9309e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.1744, MSE = 1.7894e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.4964, MSE = 2.5175e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.6947, MSE = 2.6353e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3310, MSE = 2.5134e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.7823, MSE = 1.5018e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.4274, MSE = 2.5429e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8443, MSE = 1.5178e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -0.9674, MSE = 1.9840e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.1210, MSE = 2.0742e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.3578, MSE = 2.5423e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.8292, MSE = 1.5413e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.4586, MSE = 2.5757e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.8968, MSE = 1.5609e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.0377, MSE = 2.0550e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.2043, MSE = 2.1557e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5856, MSE = 2.7879e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0288, MSE = 1.7095e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6958, MSE = 2.8241e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0935, MSE = 1.7228e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.3421, MSE = 2.3619e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.5280, MSE = 2.4722e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6646, MSE = 2.8731e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9748, MSE = 1.6640e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7589, MSE = 2.8902e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test2 -> R² = -1.0105, MSE = 1.6545e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.1948, MSE = 2.2134e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3292, MSE = 2.2778e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.4050, MSE = 2.5933e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.8040, MSE = 1.5200e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.4934, MSE = 2.6121e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -0.8569, MSE = 1.5281e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -0.9664, MSE = 1.9830e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.1024, MSE = 2.0560e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaX | train1 -> R² = -1.8483, MSE = 3.0712e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -1.2355, MSE = 1.8836e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaX | test1 -> R² = -1.9493, MSE = 3.0897e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -1.2856, MSE = 1.8809e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | test3 -> R² = -1.6058, MSE = 2.6278e-01
# 61/61 [==============================] - 0s 4ms/step
# DeltaX | val -> R² = -1.7792, MSE = 2.7179e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train1 -> R² = -1.5717, MSE = 2.7730e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -0.9908, MSE = 1.6774e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.6809, MSE = 2.8085e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.0500, MSE = 1.6870e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -1.2825, MSE = 2.3018e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4585, MSE = 2.4043e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5760, MSE = 2.7775e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | train2 -> R² = -0.9415, MSE = 1.6359e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6778, MSE = 2.8053e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -0.9889, MSE = 1.6368e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.1841, MSE = 2.2026e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3364, MSE = 2.2849e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# DeltaX | train1 -> R² = -1.5715, MSE = 2.7727e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9750, MSE = 1.6641e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.6830, MSE = 2.8108e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test2 -> R² = -1.0316, MSE = 1.6719e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2611, MSE = 2.2802e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4347, MSE = 2.3810e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.6940, MSE = 2.9048e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -1.0499, MSE = 1.7273e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test1 -> R² = -1.7799, MSE = 2.9123e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0923, MSE = 1.7218e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2870, MSE = 2.3064e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.4272, MSE = 2.3736e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaX | train1 -> R² = -1.5194, MSE = 2.7166e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train2 -> R² = -0.9727, MSE = 1.6622e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaX | test1 -> R² = -1.6173, MSE = 2.7419e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | test2 -> R² = -1.0374, MSE = 1.6766e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | test3 -> R² = -1.2275, MSE = 2.2463e-01
# 61/61 [==============================] - 0s 3ms/step
# DeltaX | val -> R² = -1.3981, MSE = 2.3452e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaX | train1 -> R² = -1.6307, MSE = 2.8365e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -0.9849, MSE = 1.6725e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.7260, MSE = 2.8558e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.0295, MSE = 1.6701e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -1.2162, MSE = 2.2350e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.3618, MSE = 2.3097e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train1 -> R² = -1.3464, MSE = 2.5300e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -0.7895, MSE = 1.5079e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.4347, MSE = 2.5506e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -0.8506, MSE = 1.5229e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -0.9508, MSE = 1.9673e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.0949, MSE = 2.0487e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train1 -> R² = -1.7884, MSE = 3.0066e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -1.2317, MSE = 1.8804e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.9013, MSE = 3.0395e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.2966, MSE = 1.8899e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -1.6591, MSE = 2.6816e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.8613, MSE = 2.7982e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train1 -> R² = -1.6919, MSE = 2.9026e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -1.0132, MSE = 1.6963e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.7790, MSE = 2.9113e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.0490, MSE = 1.6862e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -1.2296, MSE = 2.2485e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.3610, MSE = 2.3090e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train1 -> R² = -1.6262, MSE = 2.8317e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | train2 -> R² = -1.0413, MSE = 1.7200e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test1 -> R² = -1.7313, MSE = 2.8614e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaX | test2 -> R² = -1.0992, MSE = 1.7275e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | test3 -> R² = -1.3454, MSE = 2.3653e-01
# 61/61 [==============================] - 0s 2ms/step
# DeltaX | val -> R² = -1.5197, MSE = 2.4641e-01
# Modelo 2 treinado e salvo no Excel
