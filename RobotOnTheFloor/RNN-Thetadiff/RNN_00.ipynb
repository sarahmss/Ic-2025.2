# %% [markdown]
# # RNN simples com a diferença

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Pwmd, Pwme
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]
TARGET = "Theta"       

for i in range(3):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
        
    # Ajusta índice pelo tempo
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)    
    Datasets.append(Dataset)

    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Dataset.head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#         X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE
# 0.00  0.0  0.7   0.00  0.00  0.0  -0.00   0.00  -0.00   0.00
# 0.07  0.0  0.7   0.00  0.00  0.0   3.02   3.02  -0.00   0.00
# 0.14  0.0  0.7   0.00  0.00  0.0   3.02   3.02  45.32  45.32
# 0.21  0.0  0.7   0.01  0.36  0.0   3.02   3.02  45.32  45.32
# 0.28  0.0  0.7   0.01  0.20  0.0   2.99   3.02  57.60  63.38
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#         X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE
# 0.00  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00
# 0.07  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00
# 0.14  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32
# 0.21  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32
# 0.28  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#         X    Y  Theta   Wd   We  WdRef  WeRef   PwmD   PwmE
# 0.00  0.0  0.7    0.0  0.0  0.0  -0.00   0.00  -0.00   0.00
# 0.07  0.0  0.7    0.0  0.0  0.0   3.28   3.28  -0.00   0.00
# 0.14  0.0  0.7    0.0  0.0  0.0   3.28   3.28  49.25  49.25
# 0.21  0.0  0.7    0.0  0.0  0.0   3.28   3.28  49.25  49.25
# 0.28  0.0  0.7    0.0  0.0  0.0   3.28   3.28  68.95  68.95

# %%
for  i in range(3):
    Dataset = Datasets[i].copy()
    Dataset["DeltaTheta"] = Dataset[TARGET].shift(-1) - Dataset[TARGET]
    
    Dataset = Dataset.dropna(subset=["DeltaTheta"])
    Datasets[i] = Dataset
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#           X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaTheta
# 99.05  0.05  0.65  -0.83 -2.76 -3.35  -2.84  -3.05 -103.15 -117.71         0.0
# 99.12  0.05  0.65  -0.83 -2.79 -3.12  -2.86  -3.06 -104.13 -115.63         0.0
# 99.19  0.04  0.66  -0.83 -3.29 -3.18  -2.88  -3.06 -104.13 -115.63         0.0
# 99.26  0.04  0.66  -0.83 -3.26 -3.18  -2.86  -3.05  -96.76 -116.39         0.0
# 99.33  0.03  0.67  -0.83 -3.09 -3.01  -2.84  -3.05  -96.76 -116.39         0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#           X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaTheta
# 88.62  0.04  0.65  -0.78 -2.73 -2.65  -2.95  -2.66 -108.21 -110.17        0.00
# 88.69  0.04  0.65  -0.78 -2.54 -2.54  -2.94  -2.65 -108.21 -110.17       -0.01
# 88.76  0.04  0.65  -0.79 -2.87 -2.59  -2.93  -2.62 -113.11 -112.34       -0.01
# 88.83  0.03  0.66  -0.80 -3.07 -2.68  -2.92  -2.61 -113.11 -112.34       -0.01
# 88.90  0.03  0.66  -0.81 -2.98 -2.37  -2.91  -2.59 -107.17 -110.25       -0.01
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#           X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaTheta
# 68.88  0.05  0.65  -0.79 -3.40 -3.40  -3.25  -3.28  -99.77 -114.34        0.00
# 68.95  0.05  0.65  -0.79 -3.32 -3.34  -3.25  -3.28  -99.77 -114.34        0.00
# 69.02  0.04  0.66  -0.79 -3.07 -3.26  -3.25  -3.28  -99.62 -115.43        0.01
# 69.09  0.04  0.66  -0.78 -3.04 -3.18  -3.27  -3.29  -99.62 -115.43        0.00
# 69.16  0.03  0.67  -0.78 -3.26 -3.40  -3.29  -3.26 -103.96 -117.31        0.00

# %%
NormDatasets = []
TARGET = ["DeltaTheta"]

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(2):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#         X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  DeltaTheta
# 0.00  0.0  0.7   0.00  0.00  0.0  -0.00   0.00  0.463678  0.398857    0.034019
# 0.07  0.0  0.7   0.00  0.00  0.0   3.02   3.02  0.463678  0.398857    0.034019
# 0.14  0.0  0.7   0.00  0.00  0.0   3.02   3.02  1.081737  0.886844    0.616022
# 0.21  0.0  0.7   0.01  0.36  0.0   3.02   3.02  1.081737  0.886844    0.034019
# 0.28  0.0  0.7   0.01  0.20  0.0   2.99   3.02  1.249208  1.081307    0.034019
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#         X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  DeltaTheta
# 0.00  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  0.463678  0.398857    0.034019
# 0.07  0.0  0.7    0.0  0.00  0.0   3.02   3.02  0.463678  0.398857    0.034019
# 0.14  0.0  0.7    0.0  0.00  0.0   3.02   3.02  1.081737  0.886844    0.034019
# 0.21  0.0  0.7    0.0  0.03  0.0   3.02   3.02  1.081737  0.886844    0.034019
# 0.28  0.0  0.7    0.0  0.00  0.0   3.02   3.02  1.322851  1.081953    0.034019

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train = TrainDataset[PREDICTORS]
y_train = TrainDataset[TARGET]

TIME_STEPS = 3

x_train, y_train = CreateSequences(x_train, y_train, TIME_STEPS)

x_val = (NormDatasets[1])[PREDICTORS]
y_val = (NormDatasets[1])[TARGET]

x_val, y_val = CreateSequences(x_val, y_val, TIME_STEPS)


print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (1417, 3, 2)
# Dimensão da saida: (1417, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)        
        
        # valor inicial de theta no dataset original (não normalizado)
        theta0 = Datasets[i]["Theta"].iloc[0]  
        
        # reconstrução: soma cumulativa
        y_real = theta0 + np.cumsum(y_diff, axis=0)
        y_pred = theta0 + np.cumsum(y_pred_diff, axis=0)
        
        # métricas no espaço de θ
        R2 = r2_score(y_real, y_pred)
        MSE = mean_squared_error(y_real, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        # plota saída
        PlotOut(axs[i], TITLES[i], y_real, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 

model = keras.models.Sequential([
    keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)),
    keras.layers.SimpleRNN(1, activation="tanh"),
    keras.layers.Dense(OUTPUT_SIZE, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 1)              │             4 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6 (24.00 B)
#  Trainable params: 6 (24.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[-0.8120976],
#        [ 0.7811192]], dtype=float32), array([[-1.]], dtype=float32), array([0.], dtype=float32), array([[0.71221554]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=25,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.1982 - val_loss: 1.2227
# Epoch 2/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2380 - val_loss: 1.1852
# Epoch 3/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1995 - val_loss: 1.1540
# Epoch 4/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2851 - val_loss: 1.1276
# Epoch 5/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0432 - val_loss: 1.1039
# Epoch 6/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0981 - val_loss: 1.0832
# Epoch 7/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1247 - val_loss: 1.0644
# Epoch 8/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0737 - val_loss: 1.0482
# Epoch 9/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0975 - val_loss: 1.0330
# Epoch 10/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0872 - val_loss: 1.0197
# Epoch 11/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1416 - val_loss: 1.0078
# Epoch 12/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1017 - val_loss: 0.9966
# Epoch 13/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0054 - val_loss: 0.9866
# Epoch 14/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0691 - val_loss: 0.9774
# Epoch 15/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0633 - val_loss: 0.9694
# Epoch 16/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9766 - val_loss: 0.9624
# Epoch 17/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0802 - val_loss: 0.9554
# Epoch 18/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0898 - val_loss: 0.9493
# Epoch 19/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0970 - val_loss: 0.9438
# Epoch 20/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0338 - val_loss: 0.9385
# Epoch 21/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0848 - val_loss: 0.9336
# Epoch 22/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0516 - val_loss: 0.9291
# Epoch 23/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0440 - val_loss: 0.9245
# Epoch 24/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8959 - val_loss: 0.9201
# Epoch 25/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9763 - val_loss: 0.9155
# Epoch 26/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9987 - val_loss: 0.9107
# Epoch 27/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0023 - val_loss: 0.9055
# Epoch 28/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8976 - val_loss: 0.8999
# Epoch 29/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9803 - val_loss: 0.8929
# Epoch 30/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8423 - val_loss: 0.8854
# Epoch 31/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9306 - val_loss: 0.8766
# Epoch 32/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9318 - val_loss: 0.8670
# Epoch 33/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0023 - val_loss: 0.8559
# Epoch 34/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8796 - val_loss: 0.8435
# Epoch 35/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8151 - val_loss: 0.8309
# Epoch 36/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9196 - val_loss: 0.8165
# Epoch 37/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9004 - val_loss: 0.8016
# Epoch 38/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8210 - val_loss: 0.7846
# Epoch 39/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8199 - val_loss: 0.7671
# Epoch 40/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9146 - val_loss: 0.7476
# Epoch 41/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8451 - val_loss: 0.7282
# Epoch 42/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8108 - val_loss: 0.7108
# Epoch 43/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7241 - val_loss: 0.6941
# Epoch 44/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7214 - val_loss: 0.6818
# Epoch 45/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7465 - val_loss: 0.6726
# Epoch 46/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7110 - val_loss: 0.6658
# Epoch 47/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6505 - val_loss: 0.6598
# Epoch 48/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6013 - val_loss: 0.6577
# Epoch 49/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6812 - val_loss: 0.6606
# Epoch 50/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7720 - val_loss: 0.6545
# Epoch 51/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6640 - val_loss: 0.6558
# Epoch 52/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6394 - val_loss: 0.6548
# Epoch 53/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6514 - val_loss: 0.6582
# Epoch 54/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7035 - val_loss: 0.6659
# Epoch 55/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6744 - val_loss: 0.6603
# Epoch 56/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7044 - val_loss: 0.6618
# Epoch 57/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8125 - val_loss: 0.6620
# Epoch 58/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6758 - val_loss: 0.6623
# Epoch 59/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8166 - val_loss: 0.6699
# Epoch 60/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6629 - val_loss: 0.6631
# Epoch 61/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7606 - val_loss: 0.6622
# Epoch 62/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6357 - val_loss: 0.6631
# Epoch 63/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6967 - val_loss: 0.6617
# Epoch 64/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6628 - val_loss: 0.6619
# Epoch 65/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7000 - val_loss: 0.6641
# Epoch 66/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7177 - val_loss: 0.6747
# Epoch 67/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6693 - val_loss: 0.6703
# Epoch 68/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7030 - val_loss: 0.6651
# Epoch 69/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6042 - val_loss: 0.6635
# Epoch 70/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6948 - val_loss: 0.6647
# Epoch 71/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7724 - val_loss: 0.6641
# Epoch 72/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6718 - val_loss: 0.6627
# Epoch 73/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6421 - val_loss: 0.6679
# Epoch 74/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5811 - val_loss: 0.6627
# Epoch 75/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6868 - val_loss: 0.6690

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[-0.9095374],
#        [ 0.8954567]], dtype=float32), array([[-1.6767174]], dtype=float32), array([-0.02149852], dtype=float32), array([[-0.9108295]], dtype=float32), array([0.01228855], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R²_Training = 0.7104045455203218
# MSE_Training = 0.09520376534088967
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Validation = -2.9472378444625638
# MSE_Validation = 1.2918507960269674
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 1 = -4.717179473244196
# MSE_Test 1 = 1.635141352581163
