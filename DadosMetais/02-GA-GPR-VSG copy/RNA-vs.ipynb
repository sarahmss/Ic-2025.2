# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

# %%
Dataset = pd.read_excel("../Dados/Dados.xlsx")

Datasets = []

for n in range(1, 6):
    n_data = Dataset[ Dataset["Pontos"] == f"P{n}"]
    n_data = n_data.drop(columns=["Campanhas", "Pontos"])
    
    n_data_norm = n_data
        
    Datasets.append(n_data)

# %% [markdown]
# # RNA

# %%
def PrepareData(VirtualDataset, OriginalDataset, target, predictors):
    X_orig = OriginalDataset[predictors].values
    Y_orig = OriginalDataset[target].values
    
    Xv = VirtualDataset[predictors].values
    Yv = VirtualDataset[target].values
    
    X_train, X_test, Y_train, Y_test = train_test_split(
        X_orig, Y_orig, test_size=0.2, random_state=42
    )
    
    x_train = SCALER.fit_transform(X_train)
    x_test  = SCALER.transform(X_test)
        
    # CONCATENAÇÃO CORRETA
    x_train = np.concatenate((x_train, Xv), axis=0)
    y_train = np.concatenate((Y_train, Yv), axis=0)

    
    return x_train, x_test, y_train, Y_test

    
def PrintDim(x, y):
    print(f"Dimensão da entrada: {np.shape(x)}")
    print(f"Dimensão da saida: {np.shape(y)}")

# %%
from sklearn.metrics import mean_squared_error, r2_score

def TrainANN(
    x_train, y_train,
    x_test, y_test,
    n_hidden=[],
    lr=1e-3,
    l2_reg=1e-4,
    epochs=500,
    batch_size=8,
    verbose=0
):
    n_inputs = x_train.shape[1]

    # ======================
    # Modelo
    # ======================
    model = Sequential()

    model.add(
        Dense(
            n_hidden[0],
            activation="relu",
            kernel_regularizer=l2(l2_reg),
            input_shape=(n_inputs,)
        )
    )

    for units in n_hidden[1:]:
        model.add(
            Dense(
                units,
                activation="relu",
                kernel_regularizer=l2(l2_reg)
            )
        )

    model.add(Dense(1, activation="linear"))

    w0 = model.get_weights()


    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss="mse"
    )

    early_stop = EarlyStopping(
        monitor="val_loss",
        patience=30,
        restore_best_weights=True
    )

    # ======================
    # Treinamento
    # ======================
    history = model.fit(
        x_train, y_train,
        validation_split=0.2,
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=verbose
    )
    wf = model.get_weights()

    # ======================
    # Predições (NORMALIZADAS)
    # ======================
    y_train_pred_norm = model.predict(x_train, verbose=0)
    y_test_pred_norm  = model.predict(x_test,  verbose=0)

    # ======================
    # DESNORMALIZAÇÃO
    # ======================
    y_train_real = OUT_SCALER.inverse_transform(y_train.reshape(-1, 1)).ravel()
    y_test_real  = OUT_SCALER.inverse_transform(y_test.reshape(-1, 1)).ravel()

    y_train_pred = OUT_SCALER.inverse_transform(y_train_pred_norm).ravel()
    y_test_pred  = OUT_SCALER.inverse_transform(y_test_pred_norm).ravel()

    # ======================
    # MÉTRICAS NO ESPAÇO FÍSICO
    # ======================
    metrics = {
    "mse_train": round(mean_squared_error(y_train_real, y_train_pred), 4),
    "mse_test":  round(mean_squared_error(y_test_real,  y_test_pred), 4),
    "r2_train":  round(r2_score(y_train_real, y_train_pred), 4),
    "r2_test":   round(r2_score(y_test_real,  y_test_pred), 4)
}


    return model, history, metrics, w0, wf

# %%
neurons = [[1], [2], [4], [6], [8], [10], [14], [16], [18], [20]]
all_metrics = []
ConfDataset = pd.read_excel("./GA-GPR.xlsx")

for i in range(np.size(ConfDataset["P"])):
    P = ConfDataset.iloc[i]["P"]
    target = ConfDataset.iloc[i]["target"]
    n_comp = ConfDataset.iloc[i]["n_comp"]
    predictors = (ConfDataset.iloc[i]["predictors"]).split("; ")
    Dataset = Datasets[P-1]
        
    print(f" → {target}")
    output_dir = f"./Dados/VirtualData/P{P}"
    vs_filename = os.path.join(output_dir, f"virtual_samples_{target}.xlsx")
    VirtualDataset = pd.read_excel(vs_filename, sheet_name="orig-vs")
    x_train, x_test, y_train, y_test = PrepareData(VirtualDataset, Dataset, target, predictors)
    
    y_train = OUT_SCALER.fit_transform(y_train.reshape(-1, 1)).ravel()
    y_test  = OUT_SCALER.transform(y_test.reshape(-1, 1)).ravel()
    PrintDim(x_train, y_train)
    PrintDim(x_test, y_test)
        
        
    for neuron in neurons:
        for k in range(10):
            model, history, metrics, w0, wf = TrainANN(
                x_train, y_train,
                x_test, y_test,
                n_hidden=neuron
            )

            # adiciona metadados
            metrics.update({
                "P": P,
                "runTime": k,
                "target": target,
                "neurons": neuron[0],  # salva como int
                "W0": str([w.round(4).tolist() for w in w0]),
                "Wf": str([w.round(4).tolist() for w in wf]),
            })

            # cria DataFrame da linha atual
            df_new = pd.DataFrame([metrics])

            excel_file = "Results-vs.xlsx"
            # salva incrementalmente no Excel
            if os.path.exists(excel_file):
                df_old = pd.read_excel(excel_file)
                df_final = pd.concat([df_old, df_new], ignore_index=True)
            else:
                df_final = df_new

            df_final.to_excel(excel_file, index=False)

            print(f"Modelo P{P}_{target}_{neuron}_{k} treinado e salvo no Excel")
# Out:
#  → Fe
# Variância (%): [67.487 26.235  6.278]
# Total (%): 100.0
# Dimensão da entrada: (70, 3)
# Dimensão da saida: (70,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2025.2\tf-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# Modelo P1_Fe_[1]_0 treinado e salvo no Excel
# Modelo P1_Fe_[1]_1 treinado e salvo no Excel
# Modelo P1_Fe_[1]_2 treinado e salvo no Excel
# Modelo P1_Fe_[1]_3 treinado e salvo no Excel
# Modelo P1_Fe_[1]_4 treinado e salvo no Excel
# Modelo P1_Fe_[1]_5 treinado e salvo no Excel
# Modelo P1_Fe_[1]_6 treinado e salvo no Excel
# Modelo P1_Fe_[1]_7 treinado e salvo no Excel
# Modelo P1_Fe_[1]_8 treinado e salvo no Excel
# Modelo P1_Fe_[1]_9 treinado e salvo no Excel
# Modelo P1_Fe_[2]_0 treinado e salvo no Excel
# Modelo P1_Fe_[2]_1 treinado e salvo no Excel
# Modelo P1_Fe_[2]_2 treinado e salvo no Excel
# Modelo P1_Fe_[2]_3 treinado e salvo no Excel
# Modelo P1_Fe_[2]_4 treinado e salvo no Excel
# Modelo P1_Fe_[2]_5 treinado e salvo no Excel
# Modelo P1_Fe_[2]_6 treinado e salvo no Excel
# Modelo P1_Fe_[2]_7 treinado e salvo no Excel
# Modelo P1_Fe_[2]_8 treinado e salvo no Excel
# Modelo P1_Fe_[2]_9 treinado e salvo no Excel
# Modelo P1_Fe_[4]_0 treinado e salvo no Excel
# Modelo P1_Fe_[4]_1 treinado e salvo no Excel
# Modelo P1_Fe_[4]_2 treinado e salvo no Excel
# Modelo P1_Fe_[4]_3 treinado e salvo no Excel
# Modelo P1_Fe_[4]_4 treinado e salvo no Excel
# Modelo P1_Fe_[4]_5 treinado e salvo no Excel
# Modelo P1_Fe_[4]_6 treinado e salvo no Excel
# Modelo P1_Fe_[4]_7 treinado e salvo no Excel
# Modelo P1_Fe_[4]_8 treinado e salvo no Excel
# Modelo P1_Fe_[4]_9 treinado e salvo no Excel
# Modelo P1_Fe_[6]_0 treinado e salvo no Excel
# Modelo P1_Fe_[6]_1 treinado e salvo no Excel
# Modelo P1_Fe_[6]_2 treinado e salvo no Excel
# Modelo P1_Fe_[6]_3 treinado e salvo no Excel
# Modelo P1_Fe_[6]_4 treinado e salvo no Excel
# Modelo P1_Fe_[6]_5 treinado e salvo no Excel
# Modelo P1_Fe_[6]_6 treinado e salvo no Excel
# Modelo P1_Fe_[6]_7 treinado e salvo no Excel
# Modelo P1_Fe_[6]_8 treinado e salvo no Excel
# Modelo P1_Fe_[6]_9 treinado e salvo no Excel
# Modelo P1_Fe_[8]_0 treinado e salvo no Excel
# Modelo P1_Fe_[8]_1 treinado e salvo no Excel
# Modelo P1_Fe_[8]_2 treinado e salvo no Excel
# Modelo P1_Fe_[8]_3 treinado e salvo no Excel
# Modelo P1_Fe_[8]_4 treinado e salvo no Excel
# Modelo P1_Fe_[8]_5 treinado e salvo no Excel
# Modelo P1_Fe_[8]_6 treinado e salvo no Excel
# Modelo P1_Fe_[8]_7 treinado e salvo no Excel
# Modelo P1_Fe_[8]_8 treinado e salvo no Excel
# Modelo P1_Fe_[8]_9 treinado e salvo no Excel
# Modelo P1_Fe_[10]_0 treinado e salvo no Excel
# Modelo P1_Fe_[10]_1 treinado e salvo no Excel
# Modelo P1_Fe_[10]_2 treinado e salvo no Excel
# Modelo P1_Fe_[10]_3 treinado e salvo no Excel
# Modelo P1_Fe_[10]_4 treinado e salvo no Excel
# Modelo P1_Fe_[10]_5 treinado e salvo no Excel
# Modelo P1_Fe_[10]_6 treinado e salvo no Excel
# Modelo P1_Fe_[10]_7 treinado e salvo no Excel
# Modelo P1_Fe_[10]_8 treinado e salvo no Excel
# Modelo P1_Fe_[10]_9 treinado e salvo no Excel
# Modelo P1_Fe_[14]_0 treinado e salvo no Excel
# Modelo P1_Fe_[14]_1 treinado e salvo no Excel
# Modelo P1_Fe_[14]_2 treinado e salvo no Excel
# Modelo P1_Fe_[14]_3 treinado e salvo no Excel
# Modelo P1_Fe_[14]_4 treinado e salvo no Excel
# Modelo P1_Fe_[14]_5 treinado e salvo no Excel
# Modelo P1_Fe_[14]_6 treinado e salvo no Excel
# Modelo P1_Fe_[14]_7 treinado e salvo no Excel
# Modelo P1_Fe_[14]_8 treinado e salvo no Excel
# Modelo P1_Fe_[14]_9 treinado e salvo no Excel
# Modelo P1_Fe_[16]_0 treinado e salvo no Excel
# Modelo P1_Fe_[16]_1 treinado e salvo no Excel
# Modelo P1_Fe_[16]_2 treinado e salvo no Excel
# Modelo P1_Fe_[16]_3 treinado e salvo no Excel
# Modelo P1_Fe_[16]_4 treinado e salvo no Excel
# Modelo P1_Fe_[16]_5 treinado e salvo no Excel
# Modelo P1_Fe_[16]_6 treinado e salvo no Excel
# Modelo P1_Fe_[16]_7 treinado e salvo no Excel
# Modelo P1_Fe_[16]_8 treinado e salvo no Excel
# Modelo P1_Fe_[16]_9 treinado e salvo no Excel
# Modelo P1_Fe_[18]_0 treinado e salvo no Excel
# Modelo P1_Fe_[18]_1 treinado e salvo no Excel
# Modelo P1_Fe_[18]_2 treinado e salvo no Excel
# Modelo P1_Fe_[18]_3 treinado e salvo no Excel
# Modelo P1_Fe_[18]_4 treinado e salvo no Excel
# Modelo P1_Fe_[18]_5 treinado e salvo no Excel
# Modelo P1_Fe_[18]_6 treinado e salvo no Excel
# Modelo P1_Fe_[18]_7 treinado e salvo no Excel
# Modelo P1_Fe_[18]_8 treinado e salvo no Excel
# Modelo P1_Fe_[18]_9 treinado e salvo no Excel
# Modelo P1_Fe_[20]_0 treinado e salvo no Excel
# Modelo P1_Fe_[20]_1 treinado e salvo no Excel
# Modelo P1_Fe_[20]_2 treinado e salvo no Excel
# Modelo P1_Fe_[20]_3 treinado e salvo no Excel
# Modelo P1_Fe_[20]_4 treinado e salvo no Excel
# Modelo P1_Fe_[20]_5 treinado e salvo no Excel
# Modelo P1_Fe_[20]_6 treinado e salvo no Excel
# Modelo P1_Fe_[20]_7 treinado e salvo no Excel
# Modelo P1_Fe_[20]_8 treinado e salvo no Excel
# Modelo P1_Fe_[20]_9 treinado e salvo no Excel
#  → Al
# Variância (%): [42.361 20.796 15.362 11.026  8.147]
# Total (%): 97.692
# Dimensão da entrada: (144, 5)
# Dimensão da saida: (144,)
# Dimensão da entrada: (6, 5)
# Dimensão da saida: (6,)
# Modelo P1_Al_[1]_0 treinado e salvo no Excel
# Modelo P1_Al_[1]_1 treinado e salvo no Excel
# Modelo P1_Al_[1]_2 treinado e salvo no Excel
# Modelo P1_Al_[1]_3 treinado e salvo no Excel
# Modelo P1_Al_[1]_4 treinado e salvo no Excel
# Modelo P1_Al_[1]_5 treinado e salvo no Excel
# Modelo P1_Al_[1]_6 treinado e salvo no Excel
# Modelo P1_Al_[1]_7 treinado e salvo no Excel
# Modelo P1_Al_[1]_8 treinado e salvo no Excel
# Modelo P1_Al_[1]_9 treinado e salvo no Excel
# Modelo P1_Al_[2]_0 treinado e salvo no Excel
# Modelo P1_Al_[2]_1 treinado e salvo no Excel
# Modelo P1_Al_[2]_2 treinado e salvo no Excel
# Modelo P1_Al_[2]_3 treinado e salvo no Excel
# Modelo P1_Al_[2]_4 treinado e salvo no Excel
# Modelo P1_Al_[2]_5 treinado e salvo no Excel
# Modelo P1_Al_[2]_6 treinado e salvo no Excel
# Modelo P1_Al_[2]_7 treinado e salvo no Excel
# Modelo P1_Al_[2]_8 treinado e salvo no Excel
# Modelo P1_Al_[2]_9 treinado e salvo no Excel
# Modelo P1_Al_[4]_0 treinado e salvo no Excel
# Modelo P1_Al_[4]_1 treinado e salvo no Excel
# Modelo P1_Al_[4]_2 treinado e salvo no Excel
# Modelo P1_Al_[4]_3 treinado e salvo no Excel
# Modelo P1_Al_[4]_4 treinado e salvo no Excel
# Modelo P1_Al_[4]_5 treinado e salvo no Excel
# Modelo P1_Al_[4]_6 treinado e salvo no Excel
# Modelo P1_Al_[4]_7 treinado e salvo no Excel
# Modelo P1_Al_[4]_8 treinado e salvo no Excel
# Modelo P1_Al_[4]_9 treinado e salvo no Excel
# Modelo P1_Al_[6]_0 treinado e salvo no Excel
# Modelo P1_Al_[6]_1 treinado e salvo no Excel
# Modelo P1_Al_[6]_2 treinado e salvo no Excel
# Modelo P1_Al_[6]_3 treinado e salvo no Excel
# Modelo P1_Al_[6]_4 treinado e salvo no Excel
# Modelo P1_Al_[6]_5 treinado e salvo no Excel
# Modelo P1_Al_[6]_6 treinado e salvo no Excel
# Modelo P1_Al_[6]_7 treinado e salvo no Excel
# Modelo P1_Al_[6]_8 treinado e salvo no Excel
# Modelo P1_Al_[6]_9 treinado e salvo no Excel
# Modelo P1_Al_[8]_0 treinado e salvo no Excel
# Modelo P1_Al_[8]_1 treinado e salvo no Excel
# Modelo P1_Al_[8]_2 treinado e salvo no Excel
# Modelo P1_Al_[8]_3 treinado e salvo no Excel
# Modelo P1_Al_[8]_4 treinado e salvo no Excel
# Modelo P1_Al_[8]_5 treinado e salvo no Excel
# Modelo P1_Al_[8]_6 treinado e salvo no Excel
# Modelo P1_Al_[8]_7 treinado e salvo no Excel
# Modelo P1_Al_[8]_8 treinado e salvo no Excel
# Modelo P1_Al_[8]_9 treinado e salvo no Excel
# Modelo P1_Al_[10]_0 treinado e salvo no Excel
# Modelo P1_Al_[10]_1 treinado e salvo no Excel
# Modelo P1_Al_[10]_2 treinado e salvo no Excel
# Modelo P1_Al_[10]_3 treinado e salvo no Excel
# Modelo P1_Al_[10]_4 treinado e salvo no Excel
# Modelo P1_Al_[10]_5 treinado e salvo no Excel
# Modelo P1_Al_[10]_6 treinado e salvo no Excel
# Modelo P1_Al_[10]_7 treinado e salvo no Excel
# Modelo P1_Al_[10]_8 treinado e salvo no Excel
# Modelo P1_Al_[10]_9 treinado e salvo no Excel
# Modelo P1_Al_[14]_0 treinado e salvo no Excel
# Modelo P1_Al_[14]_1 treinado e salvo no Excel
# Modelo P1_Al_[14]_2 treinado e salvo no Excel
# Modelo P1_Al_[14]_3 treinado e salvo no Excel
# Modelo P1_Al_[14]_4 treinado e salvo no Excel
# Modelo P1_Al_[14]_5 treinado e salvo no Excel
# Modelo P1_Al_[14]_6 treinado e salvo no Excel
# Modelo P1_Al_[14]_7 treinado e salvo no Excel
# Modelo P1_Al_[14]_8 treinado e salvo no Excel
# Modelo P1_Al_[14]_9 treinado e salvo no Excel
# Modelo P1_Al_[16]_0 treinado e salvo no Excel
# Modelo P1_Al_[16]_1 treinado e salvo no Excel
# Modelo P1_Al_[16]_2 treinado e salvo no Excel
# Modelo P1_Al_[16]_3 treinado e salvo no Excel
# Modelo P1_Al_[16]_4 treinado e salvo no Excel
# Modelo P1_Al_[16]_5 treinado e salvo no Excel
# Modelo P1_Al_[16]_6 treinado e salvo no Excel
# Modelo P1_Al_[16]_7 treinado e salvo no Excel
# Modelo P1_Al_[16]_8 treinado e salvo no Excel
# Modelo P1_Al_[16]_9 treinado e salvo no Excel
# Modelo P1_Al_[18]_0 treinado e salvo no Excel
# Modelo P1_Al_[18]_1 treinado e salvo no Excel
# Modelo P1_Al_[18]_2 treinado e salvo no Excel
# Modelo P1_Al_[18]_3 treinado e salvo no Excel
# Modelo P1_Al_[18]_4 treinado e salvo no Excel
# Modelo P1_Al_[18]_5 treinado e salvo no Excel
# Modelo P1_Al_[18]_6 treinado e salvo no Excel
# Modelo P1_Al_[18]_7 treinado e salvo no Excel
# Modelo P1_Al_[18]_8 treinado e salvo no Excel
# Modelo P1_Al_[18]_9 treinado e salvo no Excel
# Modelo P1_Al_[20]_0 treinado e salvo no Excel
# Modelo P1_Al_[20]_1 treinado e salvo no Excel
# Modelo P1_Al_[20]_2 treinado e salvo no Excel
# Modelo P1_Al_[20]_3 treinado e salvo no Excel
# Modelo P1_Al_[20]_4 treinado e salvo no Excel
# Modelo P1_Al_[20]_5 treinado e salvo no Excel
# Modelo P1_Al_[20]_6 treinado e salvo no Excel
# Modelo P1_Al_[20]_7 treinado e salvo no Excel
# Modelo P1_Al_[20]_8 treinado e salvo no Excel
# Modelo P1_Al_[20]_9 treinado e salvo no Excel
#  → As
# Variância (%): [54.486 45.514]
# Total (%): 100.0
# Dimensão da entrada: (37, 2)
# Dimensão da saida: (37,)
# Dimensão da entrada: (6, 2)
# Dimensão da saida: (6,)
# Modelo P1_As_[1]_0 treinado e salvo no Excel
# Modelo P1_As_[1]_1 treinado e salvo no Excel
# Modelo P1_As_[1]_2 treinado e salvo no Excel
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000012111D76B00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Modelo P1_As_[1]_3 treinado e salvo no Excel
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000012116D951B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Modelo P1_As_[1]_4 treinado e salvo no Excel
# Modelo P1_As_[1]_5 treinado e salvo no Excel
# Modelo P1_As_[1]_6 treinado e salvo no Excel
# Modelo P1_As_[1]_7 treinado e salvo no Excel
# Modelo P1_As_[1]_8 treinado e salvo no Excel
# Modelo P1_As_[1]_9 treinado e salvo no Excel
# Modelo P1_As_[2]_0 treinado e salvo no Excel
# Modelo P1_As_[2]_1 treinado e salvo no Excel
# Modelo P1_As_[2]_2 treinado e salvo no Excel
# Modelo P1_As_[2]_3 treinado e salvo no Excel
# Modelo P1_As_[2]_4 treinado e salvo no Excel
# Modelo P1_As_[2]_5 treinado e salvo no Excel
# Modelo P1_As_[2]_6 treinado e salvo no Excel
# Modelo P1_As_[2]_7 treinado e salvo no Excel
# Modelo P1_As_[2]_8 treinado e salvo no Excel
# Modelo P1_As_[2]_9 treinado e salvo no Excel
# Modelo P1_As_[4]_0 treinado e salvo no Excel
# Modelo P1_As_[4]_1 treinado e salvo no Excel
# Modelo P1_As_[4]_2 treinado e salvo no Excel
# Modelo P1_As_[4]_3 treinado e salvo no Excel
# Modelo P1_As_[4]_4 treinado e salvo no Excel
# Modelo P1_As_[4]_5 treinado e salvo no Excel
# Modelo P1_As_[4]_6 treinado e salvo no Excel
# Modelo P1_As_[4]_7 treinado e salvo no Excel
# Modelo P1_As_[4]_8 treinado e salvo no Excel
# Modelo P1_As_[4]_9 treinado e salvo no Excel
# Modelo P1_As_[6]_0 treinado e salvo no Excel
# Modelo P1_As_[6]_1 treinado e salvo no Excel
# Modelo P1_As_[6]_2 treinado e salvo no Excel
# Modelo P1_As_[6]_3 treinado e salvo no Excel
# Modelo P1_As_[6]_4 treinado e salvo no Excel
# Modelo P1_As_[6]_5 treinado e salvo no Excel
# Modelo P1_As_[6]_6 treinado e salvo no Excel
# Modelo P1_As_[6]_7 treinado e salvo no Excel
# Modelo P1_As_[6]_8 treinado e salvo no Excel
# Modelo P1_As_[6]_9 treinado e salvo no Excel
# Modelo P1_As_[8]_0 treinado e salvo no Excel
# Modelo P1_As_[8]_1 treinado e salvo no Excel
# Modelo P1_As_[8]_2 treinado e salvo no Excel
# Modelo P1_As_[8]_3 treinado e salvo no Excel
# Modelo P1_As_[8]_4 treinado e salvo no Excel
# Modelo P1_As_[8]_5 treinado e salvo no Excel
# Modelo P1_As_[8]_6 treinado e salvo no Excel
# Modelo P1_As_[8]_7 treinado e salvo no Excel
# Modelo P1_As_[8]_8 treinado e salvo no Excel
# Modelo P1_As_[8]_9 treinado e salvo no Excel
# Modelo P1_As_[10]_0 treinado e salvo no Excel
# Modelo P1_As_[10]_1 treinado e salvo no Excel
# Modelo P1_As_[10]_2 treinado e salvo no Excel
# Modelo P1_As_[10]_3 treinado e salvo no Excel
# Modelo P1_As_[10]_4 treinado e salvo no Excel
# Modelo P1_As_[10]_5 treinado e salvo no Excel
# Modelo P1_As_[10]_6 treinado e salvo no Excel
# Modelo P1_As_[10]_7 treinado e salvo no Excel
# Modelo P1_As_[10]_8 treinado e salvo no Excel
# Modelo P1_As_[10]_9 treinado e salvo no Excel
# Modelo P1_As_[14]_0 treinado e salvo no Excel
# Modelo P1_As_[14]_1 treinado e salvo no Excel
# Modelo P1_As_[14]_2 treinado e salvo no Excel
# Modelo P1_As_[14]_3 treinado e salvo no Excel
# Modelo P1_As_[14]_4 treinado e salvo no Excel
# Modelo P1_As_[14]_5 treinado e salvo no Excel
# Modelo P1_As_[14]_6 treinado e salvo no Excel
# Modelo P1_As_[14]_7 treinado e salvo no Excel
# Modelo P1_As_[14]_8 treinado e salvo no Excel
# Modelo P1_As_[14]_9 treinado e salvo no Excel
# Modelo P1_As_[16]_0 treinado e salvo no Excel
# Modelo P1_As_[16]_1 treinado e salvo no Excel
# Modelo P1_As_[16]_2 treinado e salvo no Excel
# Modelo P1_As_[16]_3 treinado e salvo no Excel
# Modelo P1_As_[16]_4 treinado e salvo no Excel
# Modelo P1_As_[16]_5 treinado e salvo no Excel
# Modelo P1_As_[16]_6 treinado e salvo no Excel
# Modelo P1_As_[16]_7 treinado e salvo no Excel
# Modelo P1_As_[16]_8 treinado e salvo no Excel
# Modelo P1_As_[16]_9 treinado e salvo no Excel
# Modelo P1_As_[18]_0 treinado e salvo no Excel
# Modelo P1_As_[18]_1 treinado e salvo no Excel
# Modelo P1_As_[18]_2 treinado e salvo no Excel
# Modelo P1_As_[18]_3 treinado e salvo no Excel
# Modelo P1_As_[18]_4 treinado e salvo no Excel
# Modelo P1_As_[18]_5 treinado e salvo no Excel
# Modelo P1_As_[18]_6 treinado e salvo no Excel
# Modelo P1_As_[18]_7 treinado e salvo no Excel
# Modelo P1_As_[18]_8 treinado e salvo no Excel
# Modelo P1_As_[18]_9 treinado e salvo no Excel
# Modelo P1_As_[20]_0 treinado e salvo no Excel
# Modelo P1_As_[20]_1 treinado e salvo no Excel
# Modelo P1_As_[20]_2 treinado e salvo no Excel
# Modelo P1_As_[20]_3 treinado e salvo no Excel
# Modelo P1_As_[20]_4 treinado e salvo no Excel
# Modelo P1_As_[20]_5 treinado e salvo no Excel
# Modelo P1_As_[20]_6 treinado e salvo no Excel
# Modelo P1_As_[20]_7 treinado e salvo no Excel
# Modelo P1_As_[20]_8 treinado e salvo no Excel
# Modelo P1_As_[20]_9 treinado e salvo no Excel
#  → Pb
# Variância (%): [60.293 17.017 13.104]
# Total (%): 90.414
# Dimensão da entrada: (60, 3)
# Dimensão da saida: (60,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_Pb_[1]_0 treinado e salvo no Excel
# Modelo P1_Pb_[1]_1 treinado e salvo no Excel
# Modelo P1_Pb_[1]_2 treinado e salvo no Excel
# Modelo P1_Pb_[1]_3 treinado e salvo no Excel
# Modelo P1_Pb_[1]_4 treinado e salvo no Excel
# Modelo P1_Pb_[1]_5 treinado e salvo no Excel
# Modelo P1_Pb_[1]_6 treinado e salvo no Excel
# Modelo P1_Pb_[1]_7 treinado e salvo no Excel
# Modelo P1_Pb_[1]_8 treinado e salvo no Excel
# Modelo P1_Pb_[1]_9 treinado e salvo no Excel
# Modelo P1_Pb_[2]_0 treinado e salvo no Excel
# Modelo P1_Pb_[2]_1 treinado e salvo no Excel
# Modelo P1_Pb_[2]_2 treinado e salvo no Excel
# Modelo P1_Pb_[2]_3 treinado e salvo no Excel
# Modelo P1_Pb_[2]_4 treinado e salvo no Excel
# Modelo P1_Pb_[2]_5 treinado e salvo no Excel
# Modelo P1_Pb_[2]_6 treinado e salvo no Excel
# Modelo P1_Pb_[2]_7 treinado e salvo no Excel
# Modelo P1_Pb_[2]_8 treinado e salvo no Excel
# Modelo P1_Pb_[2]_9 treinado e salvo no Excel
# Modelo P1_Pb_[4]_0 treinado e salvo no Excel
# Modelo P1_Pb_[4]_1 treinado e salvo no Excel
# Modelo P1_Pb_[4]_2 treinado e salvo no Excel
# Modelo P1_Pb_[4]_3 treinado e salvo no Excel
# Modelo P1_Pb_[4]_4 treinado e salvo no Excel
# Modelo P1_Pb_[4]_5 treinado e salvo no Excel
# Modelo P1_Pb_[4]_6 treinado e salvo no Excel
# Modelo P1_Pb_[4]_7 treinado e salvo no Excel
# Modelo P1_Pb_[4]_8 treinado e salvo no Excel
# Modelo P1_Pb_[4]_9 treinado e salvo no Excel
# Modelo P1_Pb_[6]_0 treinado e salvo no Excel
# Modelo P1_Pb_[6]_1 treinado e salvo no Excel
# Modelo P1_Pb_[6]_2 treinado e salvo no Excel
# Modelo P1_Pb_[6]_3 treinado e salvo no Excel
# Modelo P1_Pb_[6]_4 treinado e salvo no Excel
# Modelo P1_Pb_[6]_5 treinado e salvo no Excel
# Modelo P1_Pb_[6]_6 treinado e salvo no Excel
# Modelo P1_Pb_[6]_7 treinado e salvo no Excel
# Modelo P1_Pb_[6]_8 treinado e salvo no Excel
# Modelo P1_Pb_[6]_9 treinado e salvo no Excel
# Modelo P1_Pb_[8]_0 treinado e salvo no Excel
# Modelo P1_Pb_[8]_1 treinado e salvo no Excel
# Modelo P1_Pb_[8]_2 treinado e salvo no Excel
# Modelo P1_Pb_[8]_3 treinado e salvo no Excel
# Modelo P1_Pb_[8]_4 treinado e salvo no Excel
# Modelo P1_Pb_[8]_5 treinado e salvo no Excel
# Modelo P1_Pb_[8]_6 treinado e salvo no Excel
# Modelo P1_Pb_[8]_7 treinado e salvo no Excel
# Modelo P1_Pb_[8]_8 treinado e salvo no Excel
# Modelo P1_Pb_[8]_9 treinado e salvo no Excel
# Modelo P1_Pb_[10]_0 treinado e salvo no Excel
# Modelo P1_Pb_[10]_1 treinado e salvo no Excel
# Modelo P1_Pb_[10]_2 treinado e salvo no Excel
# Modelo P1_Pb_[10]_3 treinado e salvo no Excel
# Modelo P1_Pb_[10]_4 treinado e salvo no Excel
# Modelo P1_Pb_[10]_5 treinado e salvo no Excel
# Modelo P1_Pb_[10]_6 treinado e salvo no Excel
# Modelo P1_Pb_[10]_7 treinado e salvo no Excel
# Modelo P1_Pb_[10]_8 treinado e salvo no Excel
# Modelo P1_Pb_[10]_9 treinado e salvo no Excel
# Modelo P1_Pb_[14]_0 treinado e salvo no Excel
# Modelo P1_Pb_[14]_1 treinado e salvo no Excel
# Modelo P1_Pb_[14]_2 treinado e salvo no Excel
# Modelo P1_Pb_[14]_3 treinado e salvo no Excel
# Modelo P1_Pb_[14]_4 treinado e salvo no Excel
# Modelo P1_Pb_[14]_5 treinado e salvo no Excel
# Modelo P1_Pb_[14]_6 treinado e salvo no Excel
# Modelo P1_Pb_[14]_7 treinado e salvo no Excel
# Modelo P1_Pb_[14]_8 treinado e salvo no Excel
# Modelo P1_Pb_[14]_9 treinado e salvo no Excel
# Modelo P1_Pb_[16]_0 treinado e salvo no Excel
# Modelo P1_Pb_[16]_1 treinado e salvo no Excel
# Modelo P1_Pb_[16]_2 treinado e salvo no Excel
# Modelo P1_Pb_[16]_3 treinado e salvo no Excel
# Modelo P1_Pb_[16]_4 treinado e salvo no Excel
# Modelo P1_Pb_[16]_5 treinado e salvo no Excel
# Modelo P1_Pb_[16]_6 treinado e salvo no Excel
# Modelo P1_Pb_[16]_7 treinado e salvo no Excel
# Modelo P1_Pb_[16]_8 treinado e salvo no Excel
# Modelo P1_Pb_[16]_9 treinado e salvo no Excel
# Modelo P1_Pb_[18]_0 treinado e salvo no Excel
# Modelo P1_Pb_[18]_1 treinado e salvo no Excel
# Modelo P1_Pb_[18]_2 treinado e salvo no Excel
# Modelo P1_Pb_[18]_3 treinado e salvo no Excel
# Modelo P1_Pb_[18]_4 treinado e salvo no Excel
# Modelo P1_Pb_[18]_5 treinado e salvo no Excel
# Modelo P1_Pb_[18]_6 treinado e salvo no Excel
# Modelo P1_Pb_[18]_7 treinado e salvo no Excel
# Modelo P1_Pb_[18]_8 treinado e salvo no Excel
# Modelo P1_Pb_[18]_9 treinado e salvo no Excel
# Modelo P1_Pb_[20]_0 treinado e salvo no Excel
# Modelo P1_Pb_[20]_1 treinado e salvo no Excel
# Modelo P1_Pb_[20]_2 treinado e salvo no Excel
# Modelo P1_Pb_[20]_3 treinado e salvo no Excel
# Modelo P1_Pb_[20]_4 treinado e salvo no Excel
# Modelo P1_Pb_[20]_5 treinado e salvo no Excel
# Modelo P1_Pb_[20]_6 treinado e salvo no Excel
# Modelo P1_Pb_[20]_7 treinado e salvo no Excel
# Modelo P1_Pb_[20]_8 treinado e salvo no Excel
# Modelo P1_Pb_[20]_9 treinado e salvo no Excel
#  → Zn
# Variância (%): [39.859 32.888 18.521]
# Total (%): 91.269
# Dimensão da entrada: (52, 3)
# Dimensão da saida: (52,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_Zn_[1]_0 treinado e salvo no Excel
# Modelo P1_Zn_[1]_1 treinado e salvo no Excel
# Modelo P1_Zn_[1]_2 treinado e salvo no Excel
# Modelo P1_Zn_[1]_3 treinado e salvo no Excel
# Modelo P1_Zn_[1]_4 treinado e salvo no Excel
# Modelo P1_Zn_[1]_5 treinado e salvo no Excel
# Modelo P1_Zn_[1]_6 treinado e salvo no Excel
# Modelo P1_Zn_[1]_7 treinado e salvo no Excel
# Modelo P1_Zn_[1]_8 treinado e salvo no Excel
# Modelo P1_Zn_[1]_9 treinado e salvo no Excel
# Modelo P1_Zn_[2]_0 treinado e salvo no Excel
# Modelo P1_Zn_[2]_1 treinado e salvo no Excel
# Modelo P1_Zn_[2]_2 treinado e salvo no Excel
# Modelo P1_Zn_[2]_3 treinado e salvo no Excel
# Modelo P1_Zn_[2]_4 treinado e salvo no Excel
# Modelo P1_Zn_[2]_5 treinado e salvo no Excel
# Modelo P1_Zn_[2]_6 treinado e salvo no Excel
# Modelo P1_Zn_[2]_7 treinado e salvo no Excel
# Modelo P1_Zn_[2]_8 treinado e salvo no Excel
# Modelo P1_Zn_[2]_9 treinado e salvo no Excel
# Modelo P1_Zn_[4]_0 treinado e salvo no Excel
# Modelo P1_Zn_[4]_1 treinado e salvo no Excel
# Modelo P1_Zn_[4]_2 treinado e salvo no Excel
# Modelo P1_Zn_[4]_3 treinado e salvo no Excel
# Modelo P1_Zn_[4]_4 treinado e salvo no Excel
# Modelo P1_Zn_[4]_5 treinado e salvo no Excel
# Modelo P1_Zn_[4]_6 treinado e salvo no Excel
# Modelo P1_Zn_[4]_7 treinado e salvo no Excel
# Modelo P1_Zn_[4]_8 treinado e salvo no Excel
# Modelo P1_Zn_[4]_9 treinado e salvo no Excel
# Modelo P1_Zn_[6]_0 treinado e salvo no Excel
# Modelo P1_Zn_[6]_1 treinado e salvo no Excel
# Modelo P1_Zn_[6]_2 treinado e salvo no Excel
# Modelo P1_Zn_[6]_3 treinado e salvo no Excel
# Modelo P1_Zn_[6]_4 treinado e salvo no Excel
# Modelo P1_Zn_[6]_5 treinado e salvo no Excel
# Modelo P1_Zn_[6]_6 treinado e salvo no Excel
# Modelo P1_Zn_[6]_7 treinado e salvo no Excel
# Modelo P1_Zn_[6]_8 treinado e salvo no Excel
# Modelo P1_Zn_[6]_9 treinado e salvo no Excel
# Modelo P1_Zn_[8]_0 treinado e salvo no Excel
# Modelo P1_Zn_[8]_1 treinado e salvo no Excel
# Modelo P1_Zn_[8]_2 treinado e salvo no Excel
# Modelo P1_Zn_[8]_3 treinado e salvo no Excel
# Modelo P1_Zn_[8]_4 treinado e salvo no Excel
# Modelo P1_Zn_[8]_5 treinado e salvo no Excel
# Modelo P1_Zn_[8]_6 treinado e salvo no Excel
# Modelo P1_Zn_[8]_7 treinado e salvo no Excel
# Modelo P1_Zn_[8]_8 treinado e salvo no Excel
# Modelo P1_Zn_[8]_9 treinado e salvo no Excel
# Modelo P1_Zn_[10]_0 treinado e salvo no Excel
# Modelo P1_Zn_[10]_1 treinado e salvo no Excel
# Modelo P1_Zn_[10]_2 treinado e salvo no Excel
# Modelo P1_Zn_[10]_3 treinado e salvo no Excel
# Modelo P1_Zn_[10]_4 treinado e salvo no Excel
# Modelo P1_Zn_[10]_5 treinado e salvo no Excel
# Modelo P1_Zn_[10]_6 treinado e salvo no Excel
# Modelo P1_Zn_[10]_7 treinado e salvo no Excel
# Modelo P1_Zn_[10]_8 treinado e salvo no Excel
# Modelo P1_Zn_[10]_9 treinado e salvo no Excel
# Modelo P1_Zn_[14]_0 treinado e salvo no Excel
# Modelo P1_Zn_[14]_1 treinado e salvo no Excel
# Modelo P1_Zn_[14]_2 treinado e salvo no Excel
# Modelo P1_Zn_[14]_3 treinado e salvo no Excel
# Modelo P1_Zn_[14]_4 treinado e salvo no Excel
# Modelo P1_Zn_[14]_5 treinado e salvo no Excel
# Modelo P1_Zn_[14]_6 treinado e salvo no Excel
# Modelo P1_Zn_[14]_7 treinado e salvo no Excel
# Modelo P1_Zn_[14]_8 treinado e salvo no Excel
# Modelo P1_Zn_[14]_9 treinado e salvo no Excel
# Modelo P1_Zn_[16]_0 treinado e salvo no Excel
# Modelo P1_Zn_[16]_1 treinado e salvo no Excel
# Modelo P1_Zn_[16]_2 treinado e salvo no Excel
# Modelo P1_Zn_[16]_3 treinado e salvo no Excel
# Modelo P1_Zn_[16]_4 treinado e salvo no Excel
# Modelo P1_Zn_[16]_5 treinado e salvo no Excel
# Modelo P1_Zn_[16]_6 treinado e salvo no Excel
# Modelo P1_Zn_[16]_7 treinado e salvo no Excel
# Modelo P1_Zn_[16]_8 treinado e salvo no Excel
# Modelo P1_Zn_[16]_9 treinado e salvo no Excel
# Modelo P1_Zn_[18]_0 treinado e salvo no Excel
# Modelo P1_Zn_[18]_1 treinado e salvo no Excel
# Modelo P1_Zn_[18]_2 treinado e salvo no Excel
# Modelo P1_Zn_[18]_3 treinado e salvo no Excel
# Modelo P1_Zn_[18]_4 treinado e salvo no Excel
# Modelo P1_Zn_[18]_5 treinado e salvo no Excel
# Modelo P1_Zn_[18]_6 treinado e salvo no Excel
# Modelo P1_Zn_[18]_7 treinado e salvo no Excel
# Modelo P1_Zn_[18]_8 treinado e salvo no Excel
# Modelo P1_Zn_[18]_9 treinado e salvo no Excel
# Modelo P1_Zn_[20]_0 treinado e salvo no Excel
# Modelo P1_Zn_[20]_1 treinado e salvo no Excel
# Modelo P1_Zn_[20]_2 treinado e salvo no Excel
# Modelo P1_Zn_[20]_3 treinado e salvo no Excel
# Modelo P1_Zn_[20]_4 treinado e salvo no Excel
# Modelo P1_Zn_[20]_5 treinado e salvo no Excel
# Modelo P1_Zn_[20]_6 treinado e salvo no Excel
# Modelo P1_Zn_[20]_7 treinado e salvo no Excel
# Modelo P1_Zn_[20]_8 treinado e salvo no Excel
# Modelo P1_Zn_[20]_9 treinado e salvo no Excel
#  → Hg
# Variância (%): [50.115 23.568 15.11   7.71 ]
# Total (%): 96.503
# Dimensão da entrada: (98, 4)
# Dimensão da saida: (98,)
# Dimensão da entrada: (6, 4)
# Dimensão da saida: (6,)
# Modelo P1_Hg_[1]_0 treinado e salvo no Excel
# Modelo P1_Hg_[1]_1 treinado e salvo no Excel
# Modelo P1_Hg_[1]_2 treinado e salvo no Excel
# Modelo P1_Hg_[1]_3 treinado e salvo no Excel
# Modelo P1_Hg_[1]_4 treinado e salvo no Excel
# Modelo P1_Hg_[1]_5 treinado e salvo no Excel
# Modelo P1_Hg_[1]_6 treinado e salvo no Excel
# Modelo P1_Hg_[1]_7 treinado e salvo no Excel
# Modelo P1_Hg_[1]_8 treinado e salvo no Excel
# Modelo P1_Hg_[1]_9 treinado e salvo no Excel
# Modelo P1_Hg_[2]_0 treinado e salvo no Excel
# Modelo P1_Hg_[2]_1 treinado e salvo no Excel
# Modelo P1_Hg_[2]_2 treinado e salvo no Excel
# Modelo P1_Hg_[2]_3 treinado e salvo no Excel
# Modelo P1_Hg_[2]_4 treinado e salvo no Excel
# Modelo P1_Hg_[2]_5 treinado e salvo no Excel
# Modelo P1_Hg_[2]_6 treinado e salvo no Excel
# Modelo P1_Hg_[2]_7 treinado e salvo no Excel
# Modelo P1_Hg_[2]_8 treinado e salvo no Excel
# Modelo P1_Hg_[2]_9 treinado e salvo no Excel
# Modelo P1_Hg_[4]_0 treinado e salvo no Excel
# Modelo P1_Hg_[4]_1 treinado e salvo no Excel
# Modelo P1_Hg_[4]_2 treinado e salvo no Excel
# Modelo P1_Hg_[4]_3 treinado e salvo no Excel
# Modelo P1_Hg_[4]_4 treinado e salvo no Excel
# Modelo P1_Hg_[4]_5 treinado e salvo no Excel
# Modelo P1_Hg_[4]_6 treinado e salvo no Excel
# Modelo P1_Hg_[4]_7 treinado e salvo no Excel
# Modelo P1_Hg_[4]_8 treinado e salvo no Excel
# Modelo P1_Hg_[4]_9 treinado e salvo no Excel
# Modelo P1_Hg_[6]_0 treinado e salvo no Excel
# Modelo P1_Hg_[6]_1 treinado e salvo no Excel
# Modelo P1_Hg_[6]_2 treinado e salvo no Excel
# Modelo P1_Hg_[6]_3 treinado e salvo no Excel
# Modelo P1_Hg_[6]_4 treinado e salvo no Excel
# Modelo P1_Hg_[6]_5 treinado e salvo no Excel
# Modelo P1_Hg_[6]_6 treinado e salvo no Excel
# Modelo P1_Hg_[6]_7 treinado e salvo no Excel
# Modelo P1_Hg_[6]_8 treinado e salvo no Excel
# Modelo P1_Hg_[6]_9 treinado e salvo no Excel
# Modelo P1_Hg_[8]_0 treinado e salvo no Excel
# Modelo P1_Hg_[8]_1 treinado e salvo no Excel
# Modelo P1_Hg_[8]_2 treinado e salvo no Excel
# Modelo P1_Hg_[8]_3 treinado e salvo no Excel
# Modelo P1_Hg_[8]_4 treinado e salvo no Excel
# Modelo P1_Hg_[8]_5 treinado e salvo no Excel
# Modelo P1_Hg_[8]_6 treinado e salvo no Excel
# Modelo P1_Hg_[8]_7 treinado e salvo no Excel
# Modelo P1_Hg_[8]_8 treinado e salvo no Excel
# Modelo P1_Hg_[8]_9 treinado e salvo no Excel
# Modelo P1_Hg_[10]_0 treinado e salvo no Excel
# Modelo P1_Hg_[10]_1 treinado e salvo no Excel
# Modelo P1_Hg_[10]_2 treinado e salvo no Excel
# Modelo P1_Hg_[10]_3 treinado e salvo no Excel
# Modelo P1_Hg_[10]_4 treinado e salvo no Excel
# Modelo P1_Hg_[10]_5 treinado e salvo no Excel
# Modelo P1_Hg_[10]_6 treinado e salvo no Excel
# Modelo P1_Hg_[10]_7 treinado e salvo no Excel
# Modelo P1_Hg_[10]_8 treinado e salvo no Excel
# Modelo P1_Hg_[10]_9 treinado e salvo no Excel
# Modelo P1_Hg_[14]_0 treinado e salvo no Excel
# Modelo P1_Hg_[14]_1 treinado e salvo no Excel
# Modelo P1_Hg_[14]_2 treinado e salvo no Excel
# Modelo P1_Hg_[14]_3 treinado e salvo no Excel
# Modelo P1_Hg_[14]_4 treinado e salvo no Excel
# Modelo P1_Hg_[14]_5 treinado e salvo no Excel
# Modelo P1_Hg_[14]_6 treinado e salvo no Excel
# Modelo P1_Hg_[14]_7 treinado e salvo no Excel
# Modelo P1_Hg_[14]_8 treinado e salvo no Excel
# Modelo P1_Hg_[14]_9 treinado e salvo no Excel
# Modelo P1_Hg_[16]_0 treinado e salvo no Excel
# Modelo P1_Hg_[16]_1 treinado e salvo no Excel
# Modelo P1_Hg_[16]_2 treinado e salvo no Excel
# Modelo P1_Hg_[16]_3 treinado e salvo no Excel
# Modelo P1_Hg_[16]_4 treinado e salvo no Excel
# Modelo P1_Hg_[16]_5 treinado e salvo no Excel
# Modelo P1_Hg_[16]_6 treinado e salvo no Excel
# Modelo P1_Hg_[16]_7 treinado e salvo no Excel
# Modelo P1_Hg_[16]_8 treinado e salvo no Excel
# Modelo P1_Hg_[16]_9 treinado e salvo no Excel
# Modelo P1_Hg_[18]_0 treinado e salvo no Excel
# Modelo P1_Hg_[18]_1 treinado e salvo no Excel
# Modelo P1_Hg_[18]_2 treinado e salvo no Excel
# Modelo P1_Hg_[18]_3 treinado e salvo no Excel
# Modelo P1_Hg_[18]_4 treinado e salvo no Excel
# Modelo P1_Hg_[18]_5 treinado e salvo no Excel
# Modelo P1_Hg_[18]_6 treinado e salvo no Excel
# Modelo P1_Hg_[18]_7 treinado e salvo no Excel
# Modelo P1_Hg_[18]_8 treinado e salvo no Excel
# Modelo P1_Hg_[18]_9 treinado e salvo no Excel
# Modelo P1_Hg_[20]_0 treinado e salvo no Excel
# Modelo P1_Hg_[20]_1 treinado e salvo no Excel
# Modelo P1_Hg_[20]_2 treinado e salvo no Excel
# Modelo P1_Hg_[20]_3 treinado e salvo no Excel
# Modelo P1_Hg_[20]_4 treinado e salvo no Excel
# Modelo P1_Hg_[20]_5 treinado e salvo no Excel
# Modelo P1_Hg_[20]_6 treinado e salvo no Excel
# Modelo P1_Hg_[20]_7 treinado e salvo no Excel
# Modelo P1_Hg_[20]_8 treinado e salvo no Excel
# Modelo P1_Hg_[20]_9 treinado e salvo no Excel
#  → Co
# Variância (%): [47.047 28.55  24.403]
# Total (%): 100.0
# Dimensão da entrada: (64, 3)
# Dimensão da saida: (64,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_Co_[1]_0 treinado e salvo no Excel
# Modelo P1_Co_[1]_1 treinado e salvo no Excel
# Modelo P1_Co_[1]_2 treinado e salvo no Excel
# Modelo P1_Co_[1]_3 treinado e salvo no Excel
# Modelo P1_Co_[1]_4 treinado e salvo no Excel
# Modelo P1_Co_[1]_5 treinado e salvo no Excel
# Modelo P1_Co_[1]_6 treinado e salvo no Excel
# Modelo P1_Co_[1]_7 treinado e salvo no Excel
# Modelo P1_Co_[1]_8 treinado e salvo no Excel
# Modelo P1_Co_[1]_9 treinado e salvo no Excel
# Modelo P1_Co_[2]_0 treinado e salvo no Excel
# Modelo P1_Co_[2]_1 treinado e salvo no Excel
# Modelo P1_Co_[2]_2 treinado e salvo no Excel
# Modelo P1_Co_[2]_3 treinado e salvo no Excel
# Modelo P1_Co_[2]_4 treinado e salvo no Excel
# Modelo P1_Co_[2]_5 treinado e salvo no Excel
# Modelo P1_Co_[2]_6 treinado e salvo no Excel
# Modelo P1_Co_[2]_7 treinado e salvo no Excel
# Modelo P1_Co_[2]_8 treinado e salvo no Excel
# Modelo P1_Co_[2]_9 treinado e salvo no Excel
# Modelo P1_Co_[4]_0 treinado e salvo no Excel
# Modelo P1_Co_[4]_1 treinado e salvo no Excel
# Modelo P1_Co_[4]_2 treinado e salvo no Excel
# Modelo P1_Co_[4]_3 treinado e salvo no Excel
# Modelo P1_Co_[4]_4 treinado e salvo no Excel
# Modelo P1_Co_[4]_5 treinado e salvo no Excel
# Modelo P1_Co_[4]_6 treinado e salvo no Excel
# Modelo P1_Co_[4]_7 treinado e salvo no Excel
# Modelo P1_Co_[4]_8 treinado e salvo no Excel
# Modelo P1_Co_[4]_9 treinado e salvo no Excel
# Modelo P1_Co_[6]_0 treinado e salvo no Excel
# Modelo P1_Co_[6]_1 treinado e salvo no Excel
# Modelo P1_Co_[6]_2 treinado e salvo no Excel
# Modelo P1_Co_[6]_3 treinado e salvo no Excel
# Modelo P1_Co_[6]_4 treinado e salvo no Excel
# Modelo P1_Co_[6]_5 treinado e salvo no Excel
# Modelo P1_Co_[6]_6 treinado e salvo no Excel
# Modelo P1_Co_[6]_7 treinado e salvo no Excel
# Modelo P1_Co_[6]_8 treinado e salvo no Excel
# Modelo P1_Co_[6]_9 treinado e salvo no Excel
# Modelo P1_Co_[8]_0 treinado e salvo no Excel
# Modelo P1_Co_[8]_1 treinado e salvo no Excel
# Modelo P1_Co_[8]_2 treinado e salvo no Excel
# Modelo P1_Co_[8]_3 treinado e salvo no Excel
# Modelo P1_Co_[8]_4 treinado e salvo no Excel
# Modelo P1_Co_[8]_5 treinado e salvo no Excel
# Modelo P1_Co_[8]_6 treinado e salvo no Excel
# Modelo P1_Co_[8]_7 treinado e salvo no Excel
# Modelo P1_Co_[8]_8 treinado e salvo no Excel
# Modelo P1_Co_[8]_9 treinado e salvo no Excel
# Modelo P1_Co_[10]_0 treinado e salvo no Excel
# Modelo P1_Co_[10]_1 treinado e salvo no Excel
# Modelo P1_Co_[10]_2 treinado e salvo no Excel
# Modelo P1_Co_[10]_3 treinado e salvo no Excel
# Modelo P1_Co_[10]_4 treinado e salvo no Excel
# Modelo P1_Co_[10]_5 treinado e salvo no Excel
# Modelo P1_Co_[10]_6 treinado e salvo no Excel
# Modelo P1_Co_[10]_7 treinado e salvo no Excel
# Modelo P1_Co_[10]_8 treinado e salvo no Excel
# Modelo P1_Co_[10]_9 treinado e salvo no Excel
# Modelo P1_Co_[14]_0 treinado e salvo no Excel
# Modelo P1_Co_[14]_1 treinado e salvo no Excel
# Modelo P1_Co_[14]_2 treinado e salvo no Excel
# Modelo P1_Co_[14]_3 treinado e salvo no Excel
# Modelo P1_Co_[14]_4 treinado e salvo no Excel
# Modelo P1_Co_[14]_5 treinado e salvo no Excel
# Modelo P1_Co_[14]_6 treinado e salvo no Excel
# Modelo P1_Co_[14]_7 treinado e salvo no Excel
# Modelo P1_Co_[14]_8 treinado e salvo no Excel
# Modelo P1_Co_[14]_9 treinado e salvo no Excel
# Modelo P1_Co_[16]_0 treinado e salvo no Excel
# Modelo P1_Co_[16]_1 treinado e salvo no Excel
# Modelo P1_Co_[16]_2 treinado e salvo no Excel
# Modelo P1_Co_[16]_3 treinado e salvo no Excel
# Modelo P1_Co_[16]_4 treinado e salvo no Excel
# Modelo P1_Co_[16]_5 treinado e salvo no Excel
# Modelo P1_Co_[16]_6 treinado e salvo no Excel
# Modelo P1_Co_[16]_7 treinado e salvo no Excel
# Modelo P1_Co_[16]_8 treinado e salvo no Excel
# Modelo P1_Co_[16]_9 treinado e salvo no Excel
# Modelo P1_Co_[18]_0 treinado e salvo no Excel
# Modelo P1_Co_[18]_1 treinado e salvo no Excel
# Modelo P1_Co_[18]_2 treinado e salvo no Excel
# Modelo P1_Co_[18]_3 treinado e salvo no Excel
# Modelo P1_Co_[18]_4 treinado e salvo no Excel
# Modelo P1_Co_[18]_5 treinado e salvo no Excel
# Modelo P1_Co_[18]_6 treinado e salvo no Excel
# Modelo P1_Co_[18]_7 treinado e salvo no Excel
# Modelo P1_Co_[18]_8 treinado e salvo no Excel
# Modelo P1_Co_[18]_9 treinado e salvo no Excel
# Modelo P1_Co_[20]_0 treinado e salvo no Excel
# Modelo P1_Co_[20]_1 treinado e salvo no Excel
# Modelo P1_Co_[20]_2 treinado e salvo no Excel
# Modelo P1_Co_[20]_3 treinado e salvo no Excel
# Modelo P1_Co_[20]_4 treinado e salvo no Excel
# Modelo P1_Co_[20]_5 treinado e salvo no Excel
# Modelo P1_Co_[20]_6 treinado e salvo no Excel
# Modelo P1_Co_[20]_7 treinado e salvo no Excel
# Modelo P1_Co_[20]_8 treinado e salvo no Excel
# Modelo P1_Co_[20]_9 treinado e salvo no Excel
#  → V
# Variância (%): [53.544 32.764 13.692]
# Total (%): 100.0
# Dimensão da entrada: (56, 3)
# Dimensão da saida: (56,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_V_[1]_0 treinado e salvo no Excel
# Modelo P1_V_[1]_1 treinado e salvo no Excel
# Modelo P1_V_[1]_2 treinado e salvo no Excel
# Modelo P1_V_[1]_3 treinado e salvo no Excel
# Modelo P1_V_[1]_4 treinado e salvo no Excel
# Modelo P1_V_[1]_5 treinado e salvo no Excel
# Modelo P1_V_[1]_6 treinado e salvo no Excel
# Modelo P1_V_[1]_7 treinado e salvo no Excel
# Modelo P1_V_[1]_8 treinado e salvo no Excel
# Modelo P1_V_[1]_9 treinado e salvo no Excel
# Modelo P1_V_[2]_0 treinado e salvo no Excel
# Modelo P1_V_[2]_1 treinado e salvo no Excel
# Modelo P1_V_[2]_2 treinado e salvo no Excel
# Modelo P1_V_[2]_3 treinado e salvo no Excel
# Modelo P1_V_[2]_4 treinado e salvo no Excel
# Modelo P1_V_[2]_5 treinado e salvo no Excel
# Modelo P1_V_[2]_6 treinado e salvo no Excel
# Modelo P1_V_[2]_7 treinado e salvo no Excel
# Modelo P1_V_[2]_8 treinado e salvo no Excel
# Modelo P1_V_[2]_9 treinado e salvo no Excel
# Modelo P1_V_[4]_0 treinado e salvo no Excel
# Modelo P1_V_[4]_1 treinado e salvo no Excel
# Modelo P1_V_[4]_2 treinado e salvo no Excel
# Modelo P1_V_[4]_3 treinado e salvo no Excel
# Modelo P1_V_[4]_4 treinado e salvo no Excel
# Modelo P1_V_[4]_5 treinado e salvo no Excel
# Modelo P1_V_[4]_6 treinado e salvo no Excel
# Modelo P1_V_[4]_7 treinado e salvo no Excel
# Modelo P1_V_[4]_8 treinado e salvo no Excel
# Modelo P1_V_[4]_9 treinado e salvo no Excel
# Modelo P1_V_[6]_0 treinado e salvo no Excel
# Modelo P1_V_[6]_1 treinado e salvo no Excel
# Modelo P1_V_[6]_2 treinado e salvo no Excel
# Modelo P1_V_[6]_3 treinado e salvo no Excel
# Modelo P1_V_[6]_4 treinado e salvo no Excel
# Modelo P1_V_[6]_5 treinado e salvo no Excel
# Modelo P1_V_[6]_6 treinado e salvo no Excel
# Modelo P1_V_[6]_7 treinado e salvo no Excel
# Modelo P1_V_[6]_8 treinado e salvo no Excel
# Modelo P1_V_[6]_9 treinado e salvo no Excel
# Modelo P1_V_[8]_0 treinado e salvo no Excel
# Modelo P1_V_[8]_1 treinado e salvo no Excel
# Modelo P1_V_[8]_2 treinado e salvo no Excel
# Modelo P1_V_[8]_3 treinado e salvo no Excel
# Modelo P1_V_[8]_4 treinado e salvo no Excel
# Modelo P1_V_[8]_5 treinado e salvo no Excel
# Modelo P1_V_[8]_6 treinado e salvo no Excel
# Modelo P1_V_[8]_7 treinado e salvo no Excel
# Modelo P1_V_[8]_8 treinado e salvo no Excel
# Modelo P1_V_[8]_9 treinado e salvo no Excel
# Modelo P1_V_[10]_0 treinado e salvo no Excel
# Modelo P1_V_[10]_1 treinado e salvo no Excel
# Modelo P1_V_[10]_2 treinado e salvo no Excel
# Modelo P1_V_[10]_3 treinado e salvo no Excel
# Modelo P1_V_[10]_4 treinado e salvo no Excel
# Modelo P1_V_[10]_5 treinado e salvo no Excel
# Modelo P1_V_[10]_6 treinado e salvo no Excel
# Modelo P1_V_[10]_7 treinado e salvo no Excel
# Modelo P1_V_[10]_8 treinado e salvo no Excel
# Modelo P1_V_[10]_9 treinado e salvo no Excel
# Modelo P1_V_[14]_0 treinado e salvo no Excel
# Modelo P1_V_[14]_1 treinado e salvo no Excel
# Modelo P1_V_[14]_2 treinado e salvo no Excel
# Modelo P1_V_[14]_3 treinado e salvo no Excel
# Modelo P1_V_[14]_4 treinado e salvo no Excel
# Modelo P1_V_[14]_5 treinado e salvo no Excel
# Modelo P1_V_[14]_6 treinado e salvo no Excel
# Modelo P1_V_[14]_7 treinado e salvo no Excel
# Modelo P1_V_[14]_8 treinado e salvo no Excel
# Modelo P1_V_[14]_9 treinado e salvo no Excel
# Modelo P1_V_[16]_0 treinado e salvo no Excel
# Modelo P1_V_[16]_1 treinado e salvo no Excel
# Modelo P1_V_[16]_2 treinado e salvo no Excel
# Modelo P1_V_[16]_3 treinado e salvo no Excel
# Modelo P1_V_[16]_4 treinado e salvo no Excel
# Modelo P1_V_[16]_5 treinado e salvo no Excel
# Modelo P1_V_[16]_6 treinado e salvo no Excel
# Modelo P1_V_[16]_7 treinado e salvo no Excel
# Modelo P1_V_[16]_8 treinado e salvo no Excel
# Modelo P1_V_[16]_9 treinado e salvo no Excel
# Modelo P1_V_[18]_0 treinado e salvo no Excel
# Modelo P1_V_[18]_1 treinado e salvo no Excel
# Modelo P1_V_[18]_2 treinado e salvo no Excel
# Modelo P1_V_[18]_3 treinado e salvo no Excel
# Modelo P1_V_[18]_4 treinado e salvo no Excel
# Modelo P1_V_[18]_5 treinado e salvo no Excel
# Modelo P1_V_[18]_6 treinado e salvo no Excel
# Modelo P1_V_[18]_7 treinado e salvo no Excel
# Modelo P1_V_[18]_8 treinado e salvo no Excel
# Modelo P1_V_[18]_9 treinado e salvo no Excel
# Modelo P1_V_[20]_0 treinado e salvo no Excel
# Modelo P1_V_[20]_1 treinado e salvo no Excel
# Modelo P1_V_[20]_2 treinado e salvo no Excel
# Modelo P1_V_[20]_3 treinado e salvo no Excel
# Modelo P1_V_[20]_4 treinado e salvo no Excel
# Modelo P1_V_[20]_5 treinado e salvo no Excel
# Modelo P1_V_[20]_6 treinado e salvo no Excel
# Modelo P1_V_[20]_7 treinado e salvo no Excel
# Modelo P1_V_[20]_8 treinado e salvo no Excel
# Modelo P1_V_[20]_9 treinado e salvo no Excel
#  → Ba
# Variância (%): [41.255 32.448 20.053]
# Total (%): 93.755
# Dimensão da entrada: (56, 3)
# Dimensão da saida: (56,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_Ba_[1]_0 treinado e salvo no Excel
# Modelo P1_Ba_[1]_1 treinado e salvo no Excel
# Modelo P1_Ba_[1]_2 treinado e salvo no Excel
# Modelo P1_Ba_[1]_3 treinado e salvo no Excel
# Modelo P1_Ba_[1]_4 treinado e salvo no Excel
# Modelo P1_Ba_[1]_5 treinado e salvo no Excel
# Modelo P1_Ba_[1]_6 treinado e salvo no Excel
# Modelo P1_Ba_[1]_7 treinado e salvo no Excel
# Modelo P1_Ba_[1]_8 treinado e salvo no Excel
# Modelo P1_Ba_[1]_9 treinado e salvo no Excel
# Modelo P1_Ba_[2]_0 treinado e salvo no Excel
# Modelo P1_Ba_[2]_1 treinado e salvo no Excel
# Modelo P1_Ba_[2]_2 treinado e salvo no Excel
# Modelo P1_Ba_[2]_3 treinado e salvo no Excel
# Modelo P1_Ba_[2]_4 treinado e salvo no Excel
# Modelo P1_Ba_[2]_5 treinado e salvo no Excel
# Modelo P1_Ba_[2]_6 treinado e salvo no Excel
# Modelo P1_Ba_[2]_7 treinado e salvo no Excel
# Modelo P1_Ba_[2]_8 treinado e salvo no Excel
# Modelo P1_Ba_[2]_9 treinado e salvo no Excel
# Modelo P1_Ba_[4]_0 treinado e salvo no Excel
# Modelo P1_Ba_[4]_1 treinado e salvo no Excel
# Modelo P1_Ba_[4]_2 treinado e salvo no Excel
# Modelo P1_Ba_[4]_3 treinado e salvo no Excel
# Modelo P1_Ba_[4]_4 treinado e salvo no Excel
# Modelo P1_Ba_[4]_5 treinado e salvo no Excel
# Modelo P1_Ba_[4]_6 treinado e salvo no Excel
# Modelo P1_Ba_[4]_7 treinado e salvo no Excel
# Modelo P1_Ba_[4]_8 treinado e salvo no Excel
# Modelo P1_Ba_[4]_9 treinado e salvo no Excel
# Modelo P1_Ba_[6]_0 treinado e salvo no Excel
# Modelo P1_Ba_[6]_1 treinado e salvo no Excel
# Modelo P1_Ba_[6]_2 treinado e salvo no Excel
# Modelo P1_Ba_[6]_3 treinado e salvo no Excel
# Modelo P1_Ba_[6]_4 treinado e salvo no Excel
# Modelo P1_Ba_[6]_5 treinado e salvo no Excel
# Modelo P1_Ba_[6]_6 treinado e salvo no Excel
# Modelo P1_Ba_[6]_7 treinado e salvo no Excel
# Modelo P1_Ba_[6]_8 treinado e salvo no Excel
# Modelo P1_Ba_[6]_9 treinado e salvo no Excel
# Modelo P1_Ba_[8]_0 treinado e salvo no Excel
# Modelo P1_Ba_[8]_1 treinado e salvo no Excel
# Modelo P1_Ba_[8]_2 treinado e salvo no Excel
# Modelo P1_Ba_[8]_3 treinado e salvo no Excel
# Modelo P1_Ba_[8]_4 treinado e salvo no Excel
# Modelo P1_Ba_[8]_5 treinado e salvo no Excel
# Modelo P1_Ba_[8]_6 treinado e salvo no Excel
# Modelo P1_Ba_[8]_7 treinado e salvo no Excel
# Modelo P1_Ba_[8]_8 treinado e salvo no Excel
# Modelo P1_Ba_[8]_9 treinado e salvo no Excel
# Modelo P1_Ba_[10]_0 treinado e salvo no Excel
# Modelo P1_Ba_[10]_1 treinado e salvo no Excel
# Modelo P1_Ba_[10]_2 treinado e salvo no Excel
# Modelo P1_Ba_[10]_3 treinado e salvo no Excel
# Modelo P1_Ba_[10]_4 treinado e salvo no Excel
# Modelo P1_Ba_[10]_5 treinado e salvo no Excel
# Modelo P1_Ba_[10]_6 treinado e salvo no Excel
# Modelo P1_Ba_[10]_7 treinado e salvo no Excel
# Modelo P1_Ba_[10]_8 treinado e salvo no Excel
# Modelo P1_Ba_[10]_9 treinado e salvo no Excel
# Modelo P1_Ba_[14]_0 treinado e salvo no Excel
# Modelo P1_Ba_[14]_1 treinado e salvo no Excel
# Modelo P1_Ba_[14]_2 treinado e salvo no Excel
# Modelo P1_Ba_[14]_3 treinado e salvo no Excel
# Modelo P1_Ba_[14]_4 treinado e salvo no Excel
# Modelo P1_Ba_[14]_5 treinado e salvo no Excel
# Modelo P1_Ba_[14]_6 treinado e salvo no Excel
# Modelo P1_Ba_[14]_7 treinado e salvo no Excel
# Modelo P1_Ba_[14]_8 treinado e salvo no Excel
# Modelo P1_Ba_[14]_9 treinado e salvo no Excel
# Modelo P1_Ba_[16]_0 treinado e salvo no Excel
# Modelo P1_Ba_[16]_1 treinado e salvo no Excel
# Modelo P1_Ba_[16]_2 treinado e salvo no Excel
# Modelo P1_Ba_[16]_3 treinado e salvo no Excel
# Modelo P1_Ba_[16]_4 treinado e salvo no Excel
# Modelo P1_Ba_[16]_5 treinado e salvo no Excel
# Modelo P1_Ba_[16]_6 treinado e salvo no Excel
# Modelo P1_Ba_[16]_7 treinado e salvo no Excel
# Modelo P1_Ba_[16]_8 treinado e salvo no Excel
# Modelo P1_Ba_[16]_9 treinado e salvo no Excel
# Modelo P1_Ba_[18]_0 treinado e salvo no Excel
# Modelo P1_Ba_[18]_1 treinado e salvo no Excel
# Modelo P1_Ba_[18]_2 treinado e salvo no Excel
# Modelo P1_Ba_[18]_3 treinado e salvo no Excel
# Modelo P1_Ba_[18]_4 treinado e salvo no Excel
# Modelo P1_Ba_[18]_5 treinado e salvo no Excel
# Modelo P1_Ba_[18]_6 treinado e salvo no Excel
# Modelo P1_Ba_[18]_7 treinado e salvo no Excel
# Modelo P1_Ba_[18]_8 treinado e salvo no Excel
# Modelo P1_Ba_[18]_9 treinado e salvo no Excel
# Modelo P1_Ba_[20]_0 treinado e salvo no Excel
# Modelo P1_Ba_[20]_1 treinado e salvo no Excel
# Modelo P1_Ba_[20]_2 treinado e salvo no Excel
# Modelo P1_Ba_[20]_3 treinado e salvo no Excel
# Modelo P1_Ba_[20]_4 treinado e salvo no Excel
# Modelo P1_Ba_[20]_5 treinado e salvo no Excel
# Modelo P1_Ba_[20]_6 treinado e salvo no Excel
# Modelo P1_Ba_[20]_7 treinado e salvo no Excel
# Modelo P1_Ba_[20]_8 treinado e salvo no Excel
# Modelo P1_Ba_[20]_9 treinado e salvo no Excel
#  → Mn
# Variância (%): [43.727 31.063 16.062]
# Total (%): 90.851
# Dimensão da entrada: (64, 3)
# Dimensão da saida: (64,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P1_Mn_[1]_0 treinado e salvo no Excel
# Modelo P1_Mn_[1]_1 treinado e salvo no Excel
# Modelo P1_Mn_[1]_2 treinado e salvo no Excel
# Modelo P1_Mn_[1]_3 treinado e salvo no Excel
# Modelo P1_Mn_[1]_4 treinado e salvo no Excel
# Modelo P1_Mn_[1]_5 treinado e salvo no Excel
# Modelo P1_Mn_[1]_6 treinado e salvo no Excel
# Modelo P1_Mn_[1]_7 treinado e salvo no Excel
# Modelo P1_Mn_[1]_8 treinado e salvo no Excel
# Modelo P1_Mn_[1]_9 treinado e salvo no Excel
# Modelo P1_Mn_[2]_0 treinado e salvo no Excel
# Modelo P1_Mn_[2]_1 treinado e salvo no Excel
# Modelo P1_Mn_[2]_2 treinado e salvo no Excel
# Modelo P1_Mn_[2]_3 treinado e salvo no Excel
# Modelo P1_Mn_[2]_4 treinado e salvo no Excel
# Modelo P1_Mn_[2]_5 treinado e salvo no Excel
# Modelo P1_Mn_[2]_6 treinado e salvo no Excel
# Modelo P1_Mn_[2]_7 treinado e salvo no Excel
# Modelo P1_Mn_[2]_8 treinado e salvo no Excel
# Modelo P1_Mn_[2]_9 treinado e salvo no Excel
# Modelo P1_Mn_[4]_0 treinado e salvo no Excel
# Modelo P1_Mn_[4]_1 treinado e salvo no Excel
# Modelo P1_Mn_[4]_2 treinado e salvo no Excel
# Modelo P1_Mn_[4]_3 treinado e salvo no Excel
# Modelo P1_Mn_[4]_4 treinado e salvo no Excel
# Modelo P1_Mn_[4]_5 treinado e salvo no Excel
# Modelo P1_Mn_[4]_6 treinado e salvo no Excel
# Modelo P1_Mn_[4]_7 treinado e salvo no Excel
# Modelo P1_Mn_[4]_8 treinado e salvo no Excel
# Modelo P1_Mn_[4]_9 treinado e salvo no Excel
# Modelo P1_Mn_[6]_0 treinado e salvo no Excel
# Modelo P1_Mn_[6]_1 treinado e salvo no Excel
# Modelo P1_Mn_[6]_2 treinado e salvo no Excel
# Modelo P1_Mn_[6]_3 treinado e salvo no Excel
# Modelo P1_Mn_[6]_4 treinado e salvo no Excel
# Modelo P1_Mn_[6]_5 treinado e salvo no Excel
# Modelo P1_Mn_[6]_6 treinado e salvo no Excel
# Modelo P1_Mn_[6]_7 treinado e salvo no Excel
# Modelo P1_Mn_[6]_8 treinado e salvo no Excel
# Modelo P1_Mn_[6]_9 treinado e salvo no Excel
# Modelo P1_Mn_[8]_0 treinado e salvo no Excel
# Modelo P1_Mn_[8]_1 treinado e salvo no Excel
# Modelo P1_Mn_[8]_2 treinado e salvo no Excel
# Modelo P1_Mn_[8]_3 treinado e salvo no Excel
# Modelo P1_Mn_[8]_4 treinado e salvo no Excel
# Modelo P1_Mn_[8]_5 treinado e salvo no Excel
# Modelo P1_Mn_[8]_6 treinado e salvo no Excel
# Modelo P1_Mn_[8]_7 treinado e salvo no Excel
# Modelo P1_Mn_[8]_8 treinado e salvo no Excel
# Modelo P1_Mn_[8]_9 treinado e salvo no Excel
# Modelo P1_Mn_[10]_0 treinado e salvo no Excel
# Modelo P1_Mn_[10]_1 treinado e salvo no Excel
# Modelo P1_Mn_[10]_2 treinado e salvo no Excel
# Modelo P1_Mn_[10]_3 treinado e salvo no Excel
# Modelo P1_Mn_[10]_4 treinado e salvo no Excel
# Modelo P1_Mn_[10]_5 treinado e salvo no Excel
# Modelo P1_Mn_[10]_6 treinado e salvo no Excel
# Modelo P1_Mn_[10]_7 treinado e salvo no Excel
# Modelo P1_Mn_[10]_8 treinado e salvo no Excel
# Modelo P1_Mn_[10]_9 treinado e salvo no Excel
# Modelo P1_Mn_[14]_0 treinado e salvo no Excel
# Modelo P1_Mn_[14]_1 treinado e salvo no Excel
# Modelo P1_Mn_[14]_2 treinado e salvo no Excel
# Modelo P1_Mn_[14]_3 treinado e salvo no Excel
# Modelo P1_Mn_[14]_4 treinado e salvo no Excel
# Modelo P1_Mn_[14]_5 treinado e salvo no Excel
# Modelo P1_Mn_[14]_6 treinado e salvo no Excel
# Modelo P1_Mn_[14]_7 treinado e salvo no Excel
# Modelo P1_Mn_[14]_8 treinado e salvo no Excel
# Modelo P1_Mn_[14]_9 treinado e salvo no Excel
# Modelo P1_Mn_[16]_0 treinado e salvo no Excel
# Modelo P1_Mn_[16]_1 treinado e salvo no Excel
# Modelo P1_Mn_[16]_2 treinado e salvo no Excel
# Modelo P1_Mn_[16]_3 treinado e salvo no Excel
# Modelo P1_Mn_[16]_4 treinado e salvo no Excel
# Modelo P1_Mn_[16]_5 treinado e salvo no Excel
# Modelo P1_Mn_[16]_6 treinado e salvo no Excel
# Modelo P1_Mn_[16]_7 treinado e salvo no Excel
# Modelo P1_Mn_[16]_8 treinado e salvo no Excel
# ...
# Modelo P5_Co_[10]_8 treinado e salvo no Excel
# Modelo P5_Co_[10]_9 treinado e salvo no Excel
# Modelo P5_Co_[14]_0 treinado e salvo no Excel
# Modelo P5_Co_[14]_1 treinado e salvo no Excel
# Modelo P5_Co_[14]_2 treinado e salvo no Excel
# Modelo P5_Co_[14]_3 treinado e salvo no Excel
# Modelo P5_Co_[14]_4 treinado e salvo no Excel
# Modelo P5_Co_[14]_5 treinado e salvo no Excel
# Modelo P5_Co_[14]_6 treinado e salvo no Excel
# Modelo P5_Co_[14]_7 treinado e salvo no Excel
# Modelo P5_Co_[14]_8 treinado e salvo no Excel
# Modelo P5_Co_[14]_9 treinado e salvo no Excel
# Modelo P5_Co_[16]_0 treinado e salvo no Excel
# Modelo P5_Co_[16]_1 treinado e salvo no Excel
# Modelo P5_Co_[16]_2 treinado e salvo no Excel
# Modelo P5_Co_[16]_3 treinado e salvo no Excel
# Modelo P5_Co_[16]_4 treinado e salvo no Excel
# Modelo P5_Co_[16]_5 treinado e salvo no Excel
# Modelo P5_Co_[16]_6 treinado e salvo no Excel
# Modelo P5_Co_[16]_7 treinado e salvo no Excel
# Modelo P5_Co_[16]_8 treinado e salvo no Excel
# Modelo P5_Co_[16]_9 treinado e salvo no Excel
# Modelo P5_Co_[18]_0 treinado e salvo no Excel
# Modelo P5_Co_[18]_1 treinado e salvo no Excel
# Modelo P5_Co_[18]_2 treinado e salvo no Excel
# Modelo P5_Co_[18]_3 treinado e salvo no Excel
# Modelo P5_Co_[18]_4 treinado e salvo no Excel
# Modelo P5_Co_[18]_5 treinado e salvo no Excel
# Modelo P5_Co_[18]_6 treinado e salvo no Excel
# Modelo P5_Co_[18]_7 treinado e salvo no Excel
# Modelo P5_Co_[18]_8 treinado e salvo no Excel
# Modelo P5_Co_[18]_9 treinado e salvo no Excel
# Modelo P5_Co_[20]_0 treinado e salvo no Excel
# Modelo P5_Co_[20]_1 treinado e salvo no Excel
# Modelo P5_Co_[20]_2 treinado e salvo no Excel
# Modelo P5_Co_[20]_3 treinado e salvo no Excel
# Modelo P5_Co_[20]_4 treinado e salvo no Excel
# Modelo P5_Co_[20]_5 treinado e salvo no Excel
# Modelo P5_Co_[20]_6 treinado e salvo no Excel
# Modelo P5_Co_[20]_7 treinado e salvo no Excel
# Modelo P5_Co_[20]_8 treinado e salvo no Excel
# Modelo P5_Co_[20]_9 treinado e salvo no Excel
#  → V
# Variância (%): [7.8662e+01 2.1331e+01 7.0000e-03]
# Total (%): 100.0
# Dimensão da entrada: (48, 3)
# Dimensão da saida: (48,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P5_V_[1]_0 treinado e salvo no Excel
# Modelo P5_V_[1]_1 treinado e salvo no Excel
# Modelo P5_V_[1]_2 treinado e salvo no Excel
# Modelo P5_V_[1]_3 treinado e salvo no Excel
# Modelo P5_V_[1]_4 treinado e salvo no Excel
# Modelo P5_V_[1]_5 treinado e salvo no Excel
# Modelo P5_V_[1]_6 treinado e salvo no Excel
# Modelo P5_V_[1]_7 treinado e salvo no Excel
# Modelo P5_V_[1]_8 treinado e salvo no Excel
# Modelo P5_V_[1]_9 treinado e salvo no Excel
# Modelo P5_V_[2]_0 treinado e salvo no Excel
# Modelo P5_V_[2]_1 treinado e salvo no Excel
# Modelo P5_V_[2]_2 treinado e salvo no Excel
# Modelo P5_V_[2]_3 treinado e salvo no Excel
# Modelo P5_V_[2]_4 treinado e salvo no Excel
# Modelo P5_V_[2]_5 treinado e salvo no Excel
# Modelo P5_V_[2]_6 treinado e salvo no Excel
# Modelo P5_V_[2]_7 treinado e salvo no Excel
# Modelo P5_V_[2]_8 treinado e salvo no Excel
# Modelo P5_V_[2]_9 treinado e salvo no Excel
# Modelo P5_V_[4]_0 treinado e salvo no Excel
# Modelo P5_V_[4]_1 treinado e salvo no Excel
# Modelo P5_V_[4]_2 treinado e salvo no Excel
# Modelo P5_V_[4]_3 treinado e salvo no Excel
# Modelo P5_V_[4]_4 treinado e salvo no Excel
# Modelo P5_V_[4]_5 treinado e salvo no Excel
# Modelo P5_V_[4]_6 treinado e salvo no Excel
# Modelo P5_V_[4]_7 treinado e salvo no Excel
# Modelo P5_V_[4]_8 treinado e salvo no Excel
# Modelo P5_V_[4]_9 treinado e salvo no Excel
# Modelo P5_V_[6]_0 treinado e salvo no Excel
# Modelo P5_V_[6]_1 treinado e salvo no Excel
# Modelo P5_V_[6]_2 treinado e salvo no Excel
# Modelo P5_V_[6]_3 treinado e salvo no Excel
# Modelo P5_V_[6]_4 treinado e salvo no Excel
# Modelo P5_V_[6]_5 treinado e salvo no Excel
# Modelo P5_V_[6]_6 treinado e salvo no Excel
# Modelo P5_V_[6]_7 treinado e salvo no Excel
# Modelo P5_V_[6]_8 treinado e salvo no Excel
# Modelo P5_V_[6]_9 treinado e salvo no Excel
# Modelo P5_V_[8]_0 treinado e salvo no Excel
# Modelo P5_V_[8]_1 treinado e salvo no Excel
# Modelo P5_V_[8]_2 treinado e salvo no Excel
# Modelo P5_V_[8]_3 treinado e salvo no Excel
# Modelo P5_V_[8]_4 treinado e salvo no Excel
# Modelo P5_V_[8]_5 treinado e salvo no Excel
# Modelo P5_V_[8]_6 treinado e salvo no Excel
# Modelo P5_V_[8]_7 treinado e salvo no Excel
# Modelo P5_V_[8]_8 treinado e salvo no Excel
# Modelo P5_V_[8]_9 treinado e salvo no Excel
# Modelo P5_V_[10]_0 treinado e salvo no Excel
# Modelo P5_V_[10]_1 treinado e salvo no Excel
# Modelo P5_V_[10]_2 treinado e salvo no Excel
# Modelo P5_V_[10]_3 treinado e salvo no Excel
# Modelo P5_V_[10]_4 treinado e salvo no Excel
# Modelo P5_V_[10]_5 treinado e salvo no Excel
# Modelo P5_V_[10]_6 treinado e salvo no Excel
# Modelo P5_V_[10]_7 treinado e salvo no Excel
# Modelo P5_V_[10]_8 treinado e salvo no Excel
# Modelo P5_V_[10]_9 treinado e salvo no Excel
# Modelo P5_V_[14]_0 treinado e salvo no Excel
# Modelo P5_V_[14]_1 treinado e salvo no Excel
# Modelo P5_V_[14]_2 treinado e salvo no Excel
# Modelo P5_V_[14]_3 treinado e salvo no Excel
# Modelo P5_V_[14]_4 treinado e salvo no Excel
# Modelo P5_V_[14]_5 treinado e salvo no Excel
# Modelo P5_V_[14]_6 treinado e salvo no Excel
# Modelo P5_V_[14]_7 treinado e salvo no Excel
# Modelo P5_V_[14]_8 treinado e salvo no Excel
# Modelo P5_V_[14]_9 treinado e salvo no Excel
# Modelo P5_V_[16]_0 treinado e salvo no Excel
# Modelo P5_V_[16]_1 treinado e salvo no Excel
# Modelo P5_V_[16]_2 treinado e salvo no Excel
# Modelo P5_V_[16]_3 treinado e salvo no Excel
# Modelo P5_V_[16]_4 treinado e salvo no Excel
# Modelo P5_V_[16]_5 treinado e salvo no Excel
# Modelo P5_V_[16]_6 treinado e salvo no Excel
# Modelo P5_V_[16]_7 treinado e salvo no Excel
# Modelo P5_V_[16]_8 treinado e salvo no Excel
# Modelo P5_V_[16]_9 treinado e salvo no Excel
# Modelo P5_V_[18]_0 treinado e salvo no Excel
# Modelo P5_V_[18]_1 treinado e salvo no Excel
# Modelo P5_V_[18]_2 treinado e salvo no Excel
# Modelo P5_V_[18]_3 treinado e salvo no Excel
# Modelo P5_V_[18]_4 treinado e salvo no Excel
# Modelo P5_V_[18]_5 treinado e salvo no Excel
# Modelo P5_V_[18]_6 treinado e salvo no Excel
# Modelo P5_V_[18]_7 treinado e salvo no Excel
# Modelo P5_V_[18]_8 treinado e salvo no Excel
# Modelo P5_V_[18]_9 treinado e salvo no Excel
# Modelo P5_V_[20]_0 treinado e salvo no Excel
# Modelo P5_V_[20]_1 treinado e salvo no Excel
# Modelo P5_V_[20]_2 treinado e salvo no Excel
# Modelo P5_V_[20]_3 treinado e salvo no Excel
# Modelo P5_V_[20]_4 treinado e salvo no Excel
# Modelo P5_V_[20]_5 treinado e salvo no Excel
# Modelo P5_V_[20]_6 treinado e salvo no Excel
# Modelo P5_V_[20]_7 treinado e salvo no Excel
# Modelo P5_V_[20]_8 treinado e salvo no Excel
# Modelo P5_V_[20]_9 treinado e salvo no Excel
#  → Ba
# Variância (%): [62.816 20.097 13.04 ]
# Total (%): 95.953
# Dimensão da entrada: (52, 3)
# Dimensão da saida: (52,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P5_Ba_[1]_0 treinado e salvo no Excel
# Modelo P5_Ba_[1]_1 treinado e salvo no Excel
# Modelo P5_Ba_[1]_2 treinado e salvo no Excel
# Modelo P5_Ba_[1]_3 treinado e salvo no Excel
# Modelo P5_Ba_[1]_4 treinado e salvo no Excel
# Modelo P5_Ba_[1]_5 treinado e salvo no Excel
# Modelo P5_Ba_[1]_6 treinado e salvo no Excel
# Modelo P5_Ba_[1]_7 treinado e salvo no Excel
# Modelo P5_Ba_[1]_8 treinado e salvo no Excel
# Modelo P5_Ba_[1]_9 treinado e salvo no Excel
# Modelo P5_Ba_[2]_0 treinado e salvo no Excel
# Modelo P5_Ba_[2]_1 treinado e salvo no Excel
# Modelo P5_Ba_[2]_2 treinado e salvo no Excel
# Modelo P5_Ba_[2]_3 treinado e salvo no Excel
# Modelo P5_Ba_[2]_4 treinado e salvo no Excel
# Modelo P5_Ba_[2]_5 treinado e salvo no Excel
# Modelo P5_Ba_[2]_6 treinado e salvo no Excel
# Modelo P5_Ba_[2]_7 treinado e salvo no Excel
# Modelo P5_Ba_[2]_8 treinado e salvo no Excel
# Modelo P5_Ba_[2]_9 treinado e salvo no Excel
# Modelo P5_Ba_[4]_0 treinado e salvo no Excel
# Modelo P5_Ba_[4]_1 treinado e salvo no Excel
# Modelo P5_Ba_[4]_2 treinado e salvo no Excel
# Modelo P5_Ba_[4]_3 treinado e salvo no Excel
# Modelo P5_Ba_[4]_4 treinado e salvo no Excel
# Modelo P5_Ba_[4]_5 treinado e salvo no Excel
# Modelo P5_Ba_[4]_6 treinado e salvo no Excel
# Modelo P5_Ba_[4]_7 treinado e salvo no Excel
# Modelo P5_Ba_[4]_8 treinado e salvo no Excel
# Modelo P5_Ba_[4]_9 treinado e salvo no Excel
# Modelo P5_Ba_[6]_0 treinado e salvo no Excel
# Modelo P5_Ba_[6]_1 treinado e salvo no Excel
# Modelo P5_Ba_[6]_2 treinado e salvo no Excel
# Modelo P5_Ba_[6]_3 treinado e salvo no Excel
# Modelo P5_Ba_[6]_4 treinado e salvo no Excel
# Modelo P5_Ba_[6]_5 treinado e salvo no Excel
# Modelo P5_Ba_[6]_6 treinado e salvo no Excel
# Modelo P5_Ba_[6]_7 treinado e salvo no Excel
# Modelo P5_Ba_[6]_8 treinado e salvo no Excel
# Modelo P5_Ba_[6]_9 treinado e salvo no Excel
# Modelo P5_Ba_[8]_0 treinado e salvo no Excel
# Modelo P5_Ba_[8]_1 treinado e salvo no Excel
# Modelo P5_Ba_[8]_2 treinado e salvo no Excel
# Modelo P5_Ba_[8]_3 treinado e salvo no Excel
# Modelo P5_Ba_[8]_4 treinado e salvo no Excel
# Modelo P5_Ba_[8]_5 treinado e salvo no Excel
# Modelo P5_Ba_[8]_6 treinado e salvo no Excel
# Modelo P5_Ba_[8]_7 treinado e salvo no Excel
# Modelo P5_Ba_[8]_8 treinado e salvo no Excel
# Modelo P5_Ba_[8]_9 treinado e salvo no Excel
# Modelo P5_Ba_[10]_0 treinado e salvo no Excel
# Modelo P5_Ba_[10]_1 treinado e salvo no Excel
# Modelo P5_Ba_[10]_2 treinado e salvo no Excel
# Modelo P5_Ba_[10]_3 treinado e salvo no Excel
# Modelo P5_Ba_[10]_4 treinado e salvo no Excel
# Modelo P5_Ba_[10]_5 treinado e salvo no Excel
# Modelo P5_Ba_[10]_6 treinado e salvo no Excel
# Modelo P5_Ba_[10]_7 treinado e salvo no Excel
# Modelo P5_Ba_[10]_8 treinado e salvo no Excel
# Modelo P5_Ba_[10]_9 treinado e salvo no Excel
# Modelo P5_Ba_[14]_0 treinado e salvo no Excel
# Modelo P5_Ba_[14]_1 treinado e salvo no Excel
# Modelo P5_Ba_[14]_2 treinado e salvo no Excel
# Modelo P5_Ba_[14]_3 treinado e salvo no Excel
# Modelo P5_Ba_[14]_4 treinado e salvo no Excel
# Modelo P5_Ba_[14]_5 treinado e salvo no Excel
# Modelo P5_Ba_[14]_6 treinado e salvo no Excel
# Modelo P5_Ba_[14]_7 treinado e salvo no Excel
# Modelo P5_Ba_[14]_8 treinado e salvo no Excel
# Modelo P5_Ba_[14]_9 treinado e salvo no Excel
# Modelo P5_Ba_[16]_0 treinado e salvo no Excel
# Modelo P5_Ba_[16]_1 treinado e salvo no Excel
# Modelo P5_Ba_[16]_2 treinado e salvo no Excel
# Modelo P5_Ba_[16]_3 treinado e salvo no Excel
# Modelo P5_Ba_[16]_4 treinado e salvo no Excel
# Modelo P5_Ba_[16]_5 treinado e salvo no Excel
# Modelo P5_Ba_[16]_6 treinado e salvo no Excel
# Modelo P5_Ba_[16]_7 treinado e salvo no Excel
# Modelo P5_Ba_[16]_8 treinado e salvo no Excel
# Modelo P5_Ba_[16]_9 treinado e salvo no Excel
# Modelo P5_Ba_[18]_0 treinado e salvo no Excel
# Modelo P5_Ba_[18]_1 treinado e salvo no Excel
# Modelo P5_Ba_[18]_2 treinado e salvo no Excel
# Modelo P5_Ba_[18]_3 treinado e salvo no Excel
# Modelo P5_Ba_[18]_4 treinado e salvo no Excel
# Modelo P5_Ba_[18]_5 treinado e salvo no Excel
# Modelo P5_Ba_[18]_6 treinado e salvo no Excel
# Modelo P5_Ba_[18]_7 treinado e salvo no Excel
# Modelo P5_Ba_[18]_8 treinado e salvo no Excel
# Modelo P5_Ba_[18]_9 treinado e salvo no Excel
# Modelo P5_Ba_[20]_0 treinado e salvo no Excel
# Modelo P5_Ba_[20]_1 treinado e salvo no Excel
# Modelo P5_Ba_[20]_2 treinado e salvo no Excel
# Modelo P5_Ba_[20]_3 treinado e salvo no Excel
# Modelo P5_Ba_[20]_4 treinado e salvo no Excel
# Modelo P5_Ba_[20]_5 treinado e salvo no Excel
# Modelo P5_Ba_[20]_6 treinado e salvo no Excel
# Modelo P5_Ba_[20]_7 treinado e salvo no Excel
# Modelo P5_Ba_[20]_8 treinado e salvo no Excel
# Modelo P5_Ba_[20]_9 treinado e salvo no Excel
#  → Mn
# Variância (%): [43.596 37.725 18.679]
# Total (%): 100.0
# Dimensão da entrada: (54, 3)
# Dimensão da saida: (54,)
# Dimensão da entrada: (6, 3)
# Dimensão da saida: (6,)
# Modelo P5_Mn_[1]_0 treinado e salvo no Excel
# Modelo P5_Mn_[1]_1 treinado e salvo no Excel
# Modelo P5_Mn_[1]_2 treinado e salvo no Excel
# Modelo P5_Mn_[1]_3 treinado e salvo no Excel
# Modelo P5_Mn_[1]_4 treinado e salvo no Excel
# Modelo P5_Mn_[1]_5 treinado e salvo no Excel
# Modelo P5_Mn_[1]_6 treinado e salvo no Excel
# Modelo P5_Mn_[1]_7 treinado e salvo no Excel
# Modelo P5_Mn_[1]_8 treinado e salvo no Excel
# Modelo P5_Mn_[1]_9 treinado e salvo no Excel
# Modelo P5_Mn_[2]_0 treinado e salvo no Excel
# Modelo P5_Mn_[2]_1 treinado e salvo no Excel
# Modelo P5_Mn_[2]_2 treinado e salvo no Excel
# Modelo P5_Mn_[2]_3 treinado e salvo no Excel
# Modelo P5_Mn_[2]_4 treinado e salvo no Excel
# Modelo P5_Mn_[2]_5 treinado e salvo no Excel
# Modelo P5_Mn_[2]_6 treinado e salvo no Excel
# Modelo P5_Mn_[2]_7 treinado e salvo no Excel
# Modelo P5_Mn_[2]_8 treinado e salvo no Excel
# Modelo P5_Mn_[2]_9 treinado e salvo no Excel
# Modelo P5_Mn_[4]_0 treinado e salvo no Excel
# Modelo P5_Mn_[4]_1 treinado e salvo no Excel
# Modelo P5_Mn_[4]_2 treinado e salvo no Excel
# Modelo P5_Mn_[4]_3 treinado e salvo no Excel
# Modelo P5_Mn_[4]_4 treinado e salvo no Excel
# Modelo P5_Mn_[4]_5 treinado e salvo no Excel
# Modelo P5_Mn_[4]_6 treinado e salvo no Excel
# Modelo P5_Mn_[4]_7 treinado e salvo no Excel
# Modelo P5_Mn_[4]_8 treinado e salvo no Excel
# Modelo P5_Mn_[4]_9 treinado e salvo no Excel
# Modelo P5_Mn_[6]_0 treinado e salvo no Excel
# Modelo P5_Mn_[6]_1 treinado e salvo no Excel
# Modelo P5_Mn_[6]_2 treinado e salvo no Excel
# Modelo P5_Mn_[6]_3 treinado e salvo no Excel
# Modelo P5_Mn_[6]_4 treinado e salvo no Excel
# Modelo P5_Mn_[6]_5 treinado e salvo no Excel
# Modelo P5_Mn_[6]_6 treinado e salvo no Excel
# Modelo P5_Mn_[6]_7 treinado e salvo no Excel
# Modelo P5_Mn_[6]_8 treinado e salvo no Excel
# Modelo P5_Mn_[6]_9 treinado e salvo no Excel
# Modelo P5_Mn_[8]_0 treinado e salvo no Excel
# Modelo P5_Mn_[8]_1 treinado e salvo no Excel
# Modelo P5_Mn_[8]_2 treinado e salvo no Excel
# Modelo P5_Mn_[8]_3 treinado e salvo no Excel
# Modelo P5_Mn_[8]_4 treinado e salvo no Excel
# Modelo P5_Mn_[8]_5 treinado e salvo no Excel
# Modelo P5_Mn_[8]_6 treinado e salvo no Excel
# Modelo P5_Mn_[8]_7 treinado e salvo no Excel
# Modelo P5_Mn_[8]_8 treinado e salvo no Excel
# Modelo P5_Mn_[8]_9 treinado e salvo no Excel
# Modelo P5_Mn_[10]_0 treinado e salvo no Excel
# Modelo P5_Mn_[10]_1 treinado e salvo no Excel
# Modelo P5_Mn_[10]_2 treinado e salvo no Excel
# Modelo P5_Mn_[10]_3 treinado e salvo no Excel
# Modelo P5_Mn_[10]_4 treinado e salvo no Excel
# Modelo P5_Mn_[10]_5 treinado e salvo no Excel
# Modelo P5_Mn_[10]_6 treinado e salvo no Excel
# Modelo P5_Mn_[10]_7 treinado e salvo no Excel
# Modelo P5_Mn_[10]_8 treinado e salvo no Excel
# Modelo P5_Mn_[10]_9 treinado e salvo no Excel
# Modelo P5_Mn_[14]_0 treinado e salvo no Excel
# Modelo P5_Mn_[14]_1 treinado e salvo no Excel
# Modelo P5_Mn_[14]_2 treinado e salvo no Excel
# Modelo P5_Mn_[14]_3 treinado e salvo no Excel
# Modelo P5_Mn_[14]_4 treinado e salvo no Excel
# Modelo P5_Mn_[14]_5 treinado e salvo no Excel
# Modelo P5_Mn_[14]_6 treinado e salvo no Excel
# Modelo P5_Mn_[14]_7 treinado e salvo no Excel
# Modelo P5_Mn_[14]_8 treinado e salvo no Excel
# Modelo P5_Mn_[14]_9 treinado e salvo no Excel
# Modelo P5_Mn_[16]_0 treinado e salvo no Excel
# Modelo P5_Mn_[16]_1 treinado e salvo no Excel
# Modelo P5_Mn_[16]_2 treinado e salvo no Excel
# Modelo P5_Mn_[16]_3 treinado e salvo no Excel
# Modelo P5_Mn_[16]_4 treinado e salvo no Excel
# Modelo P5_Mn_[16]_5 treinado e salvo no Excel
# Modelo P5_Mn_[16]_6 treinado e salvo no Excel
# Modelo P5_Mn_[16]_7 treinado e salvo no Excel
# Modelo P5_Mn_[16]_8 treinado e salvo no Excel
# Modelo P5_Mn_[16]_9 treinado e salvo no Excel
# Modelo P5_Mn_[18]_0 treinado e salvo no Excel
# Modelo P5_Mn_[18]_1 treinado e salvo no Excel
# Modelo P5_Mn_[18]_2 treinado e salvo no Excel
# Modelo P5_Mn_[18]_3 treinado e salvo no Excel
# Modelo P5_Mn_[18]_4 treinado e salvo no Excel
# Modelo P5_Mn_[18]_5 treinado e salvo no Excel
# Modelo P5_Mn_[18]_6 treinado e salvo no Excel
# Modelo P5_Mn_[18]_7 treinado e salvo no Excel
# Modelo P5_Mn_[18]_8 treinado e salvo no Excel
# Modelo P5_Mn_[18]_9 treinado e salvo no Excel
# Modelo P5_Mn_[20]_0 treinado e salvo no Excel
# Modelo P5_Mn_[20]_1 treinado e salvo no Excel
# Modelo P5_Mn_[20]_2 treinado e salvo no Excel
# Modelo P5_Mn_[20]_3 treinado e salvo no Excel
# Modelo P5_Mn_[20]_4 treinado e salvo no Excel
# Modelo P5_Mn_[20]_5 treinado e salvo no Excel
# Modelo P5_Mn_[20]_6 treinado e salvo no Excel
# Modelo P5_Mn_[20]_7 treinado e salvo no Excel
# Modelo P5_Mn_[20]_8 treinado e salvo no Excel
# Modelo P5_Mn_[20]_9 treinado e salvo no Excel
